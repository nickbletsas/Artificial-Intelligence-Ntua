# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Νίκολαος Μπλέτσας 03118899
#
# Στοιχεία Μέλους 2: Δημήτριος Κοκκίνης 03118896

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="/content/drive/MyDrive/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget  ...      actor_2_name       actor_3_name
# 0           0  237000000  ...  Sigourney Weaver       Stephen Lang
# 1           1  300000000  ...   Keira Knightley  Stellan Skarsgård
# 2           2  245000000  ...       Léa Seydoux      Ralph Fiennes
# 3           3  250000000  ...       Gary Oldman      Anne Hathaway
# 4           4  260000000  ...   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()
import ast
#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  budget = clean_text(str(getattr(row, 'budget')))
  director = clean_text(getattr(row, 'director_name'))
  language = clean_text(getattr(row, 'language'))
  actor_1 = clean_text(getattr(row, 'actor_1_name'))
  actor_2 = clean_text(getattr(row, 'actor_2_name'))
  actor_3 = clean_text(getattr(row, 'actor_3_name'))
  country = clean_text(getattr(row, 'country'))
  vote_average = clean_text(str(getattr(row, 'vote_average')))
  title_year = clean_text(str(getattr(row, 'title_year')))
  gross = clean_text(str(getattr(row, 'gross')))
  duration = clean_text(str(getattr(row, 'duration')))
  release_date = clean_text(str(getattr(row, 'release_date')))

  movie_score[movie_title] = 0
  found = False

  if movie_title != "UNK":
    if budget != "UNK":
      literals.append("budget('"+ movie_title +"','" + budget + "')")
    if director != "UNK":
      literals.append("director('"+ movie_title +"','" + director + "')")
    if language != "UNK":
      literals.append("language('"+ movie_title +"','" + language + "')")
    if actor_1 != "UNK":
      literals.append("actor('"+ movie_title +"','" + actor_1 + "')")
    if actor_2 != "UNK":
      literals.append("actor('"+ movie_title +"','" + actor_2 + "')")
    if actor_3 != "UNK":
      literals.append("actor('"+ movie_title +"','" + actor_3 + "')")
    if country != "UNK":
      literals.append("country('"+ movie_title +"','" + country + "')")
    if vote_average != "UNK":
      literals.append("vote_average('"+ movie_title +"','" + vote_average + "')")
    if title_year != "UNK":
      literals.append("title_year('"+ movie_title +"','" + title_year + "')")
    if gross != "UNK":
      literals.append("gross('"+ movie_title +"','" + gross + "')")
    if duration != "UNK":
      literals.append("duration('"+ movie_title +"','" + duration + "')")
    if release_date != "UNK":
      literals.append("release_date('"+ movie_title +"','" + release_date + "')")  
  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")
  for plot_keyword in clean_text(getattr(row, 'plot_keywords')).split("|"):
      literals.append("plot_keywords('"+ movie_title +"','"+ plot_keyword +"')")
      if plot_keyword == "black and white" and found == False:
        literals.append("color('"+ movie_title +"','"+ plot_keyword +"')")  
        found = True                                                       
  if found == False:                                                      
    literals.append("color('"+ movie_title +"','"+ "color" +"')")         

     
#dictionary list       
  l=ast.literal_eval(getattr(row, 'production_companies')) #convert string to list of dictionaries
  if len(l)!=0:
    for productions_companies in l:
      literals.append("production_companies('"+ movie_title +"','" + clean_text(productions_companies['name']) +  "','" + clean_text(str(productions_companies['id'])) + "')") 

  l=ast.literal_eval(getattr(row, 'production_countries')) #convert string to list of dictionaries
  if len(l)!=0:
    for productions_countries in l:
      literals.append("production_countries('"+ movie_title +"','" + clean_text(str(productions_countries['iso_3166_1'])) +  "','" + clean_text(productions_countries['name']) + "')") 
                                                                          
#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)
#   print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %%
prolog.assertz('(commongenre_5(X,Y):-genre(X,A),genre(X,B),genre(X,C),genre(X,D),genre(X,E),genre(Y,A),genre(Y,B),genre(Y,C),genre(Y,D),genre(Y,E),X\=Y,A\=B,A\=C,A\=D,A\=E,B\=C,B\=D,B\=E,C\=D,C\=E,D\=E)')
prolog.assertz('(commongenre_4(X,Y):-genre(X,A),genre(X,B),genre(X,C),genre(X,D),genre(Y,A),genre(Y,B),genre(Y,C),genre(Y,D),X\=Y,A\=B,A\=C,A\=D,B\=C,B\=D,C\=D, not(commongenre_5(X,Y)))')
prolog.assertz('(commongenre_3(X,Y):-genre(X,A),genre(X,B),genre(X,C),genre(Y,A),genre(Y,B),genre(Y,C),X\=Y,A\=B,A\=C,B\=C, not(commongenre_4(X,Y)), not(commongenre_5(X,Y)))')
prolog.assertz('(commongenre_2(X,Y):-genre(X,A),genre(X,B),genre(Y,A),genre(Y,B),X\=Y,A\=B, not(commongenre_3(X,Y)), not(commongenre_4(X,Y)), not(commongenre_5(X,Y)))')
prolog.assertz('(commongenre_1(X,Y):-genre(X,A),genre(Y,A),X\=Y, not(commongenre_2(X,Y)), not(commongenre_3(X,Y)), not(commongenre_4(X,Y)), not(commongenre_5(X,Y)))')

# %% [markdown]
# Παραπάνω φτιάχνουμε τα κατηγορήματα για τα κοινά θέματα στις ταινίες (genres), διαφοροποιούμαστε από την εκφώνηση και ορίζουμε μια κλίμακα 1-5, όπου αριθμός είναι το πόσα κοινά genres έχει μια ταινία με μια άλλη. Στη συνέχεια ομαδοποιούμε τα παραπάνω σε πολυ κοινό θέμα, σχετικά κοινό θέμα και λίγο κοινό θέμα.
#
# 1. Πολύ κοινό θέμα έχουν όσες ταινίες έχουν 4-5 κοινά genres ( θεωρητικά είναι 4 τουλαχιστόν απλά μετά απο δοκιμές διαπιστώσαμε ότι καμία ταινία δεν έχει παραπάνω απο 5 κοινά με μια άλλη, και πολύ ελάχιστες 4-5).
# 2. Σχετικά κοινό θέμα έχουν οι ταινίες που έχουν 2-3 κοινά genres
# 1. Λίγο κοινό θέμα έχουν οι ταινίες που έχουν ένα κοινό genre.
#
# Παρακάτω, έχουμε ορίσει κάποιες συναρτήσεις για να μας δείξουν την έξοδο των κατηγορημάτων, που προσθέτουμε στη βάση γνώσης μας, με συγκεκριμένη είσοδο κάποια ταινία.

# %%
prolog.assertz('(commongenre_very(X,Y):-genre(X,A),genre(X,B),genre(X,C),genre(X,D),genre(Y,A),genre(Y,B),genre(Y,C),genre(Y,D),X\=Y,A\=B,A\=C,A\=D,B\=C,B\=D,C\=D)')
prolog.assertz('(commongenre_medium(X,Y):-genre(X,A),genre(X,B),genre(Y,A),genre(Y,B),X\=Y,A\=B, not(commongenre_4(X,Y)), not(commongenre_5(X,Y)))')
prolog.assertz('(commongenre_low(X,Y):-commongenre_1(X,Y))')

# %%
def common_genre(movie):

    q = prolog.query("commongenre_1('" + movie + "',M)")
    ans5 = []
    for soln in q:
        ans5.append(soln["M"])

    q = prolog.query("commongenre_2('" + movie + "',M)")
    ans4 = []
    for soln in q:
        ans4.append(soln["M"])

    
    q = prolog.query("commongenre_3('" + movie + "',M)")
    ans3 = []
    for soln in q:
        ans3.append(soln["M"])

    q = prolog.query("commongenre_4('" + movie +"',M)")
    ans2 = []
    for soln in q:
        ans2.append(soln["M"])
    q = prolog.query("commongenre_5('" +  movie +"',M)")
    ans1 = []
    for soln in q:
        ans1.append(soln["M"])

    return list(set(ans5))[:10], list(set(ans4))[:10], list(set(ans3))[:10], list(set(ans2))[:10], list(set(ans1))[:10]
    #return list(set(ans3))[:10], list(set(ans2))[:10], list(set(ans1))[:10]

# %%
common_genre("Avatar")
# Out:
# (['Taken 3',
#   'Hackers',
#   'Ace Ventura: When Nature Calls',
#   'Underdogs',
#   'Barbarella',
#   'Ice Age: Dawn of the Dinosaurs',
#   'The Legend of Bagger Vance',
#   'The Postman',
#   'Automata',
#   'The Jacket'],
#  ['Conquest of the Planet of the Apes',
#   'Dick Tracy',
#   'Impostor',
#   'The Devils Tomb',
#   'Somewhere in Time',
#   'Pixels',
#   'Phenomenon',
#   'Casino Royale',
#   'Exodus: Gods and Kings',
#   'Hero'],
#  ['Planet of the Apes',
#   'The Thief and the Cobbler',
#   'Cirque du Freak: The Vampires Assistant',
#   'Hellboy II: The Golden Army',
#   'Tank Girl',
#   'Jumper',
#   'Pirates of the Caribbean: Dead Mans Chest',
#   'Mortal Kombat: Annihilation',
#   'Priest',
#   'The Lord of the Rings: The Fellowship of the Ring'],
#  ['Beastmaster 2: Through the Portal of Time',
#   'Superman III',
#   'Dragonball Evolution',
#   'The Shadow',
#   'Blade: Trinity',
#   'Mystery Men',
#   'Small Soldiers',
#   'Batman',
#   'Thunderbirds',
#   'Jupiter Ascending'],
#  [])

# %%
prolog.assertz('(common_director(X, Y) :- director(X, A), director(Y, A), X \= Y )')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινό σκηνοθέτη μεταξύ δύο ταινιών.

# %%
def common_director(movie):
    q = prolog.query("common_director('" + movie +"',M)")
    ans = []
    for soln in q:
        ans.append(soln["M"])
    return list(set(ans))

# %%
common_director("Avatar")
# Out:
# ['The Abyss',
#  'True Lies',
#  'The Terminator',
#  'Terminator 2: Judgment Day',
#  'Titanic',
#  'Aliens']

# %%
prolog.assertz('(commonplot_high(X,Y):-plot_keywords(X,A),plot_keywords(X,B),plot_keywords(Y,A),plot_keywords(Y,B),X\=Y,A\=B)')
prolog.assertz('(commonplot_low(X,Y):-plot_keywords(X,A),plot_keywords(Y,A),X\=Y, not(commonplot_high(X,Y)) )')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινά στοιχεία πλοκής μεταξύ δύο ταινιών. Παρατηρήσαμε ότι δύο ταινίες έχουν το πολύ δύο στοιχεία πλοκής κοινά μεταξύ τους. Αυτό συμβαίνει γιατί οι λέξεις πλοκής είναι πολύ ειδικές ( πχ black magic, magic, sorcery κτλ ). Οπότε δεν χρησιμοποίησαμε πάλι την κλίμακα 1-5 όπως στα genres, αλλά μόνο άν κάποια ταινία έχει δύο κοινές λέξεις ή μια.

# %%
def common_plot(movie):

    q = prolog.query("commonplot_high('" + movie + "',M)")
    ans5 = []
    for soln in q:
        ans5.append(soln["M"])

    q = prolog.query("commonplot_low('" + movie + "',M)")
    ans4 = []
    for soln in q:
        ans4.append(soln["M"])
    return list(set(ans5))[:10], list(set(ans4))[:10]

# %%
common_plot("Avatar")
# Out:
# (['Terminator Genisys',
#   'Planet of the Apes',
#   'Stargate: The Ark of Truth',
#   'Alien',
#   'Platoon',
#   'You Only Live Twice',
#   'Home',
#   'Cargo',
#   'The Four Feathers',
#   'Renaissance'],
#  ['The Thief and the Cobbler',
#   'The Thing',
#   'Anna and the King',
#   'Falcon Rising',
#   'Barbarella',
#   'Wag the Dog',
#   'Impostor',
#   'Piranha 3D',
#   '2001: A Space Odyssey',
#   'RoboCop'])

# %%
prolog.assertz('(three_common_actors(X, Y) :- actor(X, A), actor(X, B), actor(X, C), actor(Y, A), actor(Y, B), actor(Y, C), X \= Y, A \= B, B \= C, C \= A )')
prolog.assertz('(two_common_actors(X, Y) :- actor(X, A), actor(X, B), actor(Y, A), actor(Y, B), X \= Y, A \= B, not(three_common_actors(X, Y)) )')
prolog.assertz('(one_common_actor(X, Y) :- actor(X, A), actor(Y, A), X \= Y, not(two_common_actors(X, Y)), not(three_common_actors(X, Y)) )')

# %% [markdown]
# Προσθήκη κατηγορημάτων για κοινούς ηθοποιούς. Συγκεκριμένα, εξετάζουν αν δύο ταινίες έχουν ακριβώς 1, 2 ή 3 ηθοποιούς κοινούς.

# %%
def common_actors(movie):
    q = prolog.query("three_common_actors('" + movie + "',M)")
    ans3 = []
    for soln in q:
        ans3.append(soln["M"])


    q = prolog.query("two_common_actors('" + movie +"',M)")
    ans2 = []
    for soln in q:
        ans2.append(soln["M"])


    q = prolog.query("one_common_actor('" + movie +"',M)")
    ans1 = []
    for soln in q:
        ans1.append(soln["M"])
 

    return list(set(ans3)) , list(set(ans2)), list(set(ans1))

# %%
common_actors("Avatar")
# Out:
# ([],
#  [],
#  ['Alien',
#   'Vamps',
#   'Drumline',
#   'Cedar Rapids',
#   'You Again',
#   'Vantage Point',
#   'Star Trek Into Darkness',
#   'The Losers',
#   'Out of the Furnace',
#   'Center Stage',
#   'The Words',
#   'Guardians of the Galaxy',
#   'Baby Mama',
#   'The Cold Light of Day',
#   'Galaxy Quest',
#   'The Ice Storm',
#   'Crossroads',
#   'Shadow Conspiracy',
#   'The Book of Life',
#   'Guess Who'])

# %%
prolog.assertz('(same_language(X, Y) :- language(X, A), language(Y, A), X \= Y )')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινή γλώσσα μεταξύ δύο ταινιών.

# %%
def same_language(movie):
    q = prolog.query("same_language('" + movie +"',M)")
    ans = []
    for soln in q:
        ans.append(soln["M"])
    return list(set(ans))

# %%
same_language("Avatar")
# Out:
# ['Conquest of the Planet of the Apes',
#  'Critical Care',
#  'Impostor',
#  'School of Rock',
#  'Casino Royale',
#  'Dolphin Tale 2',
#  'Automata',
#  'Exodus: Gods and Kings',
#  'Rocky Balboa',
#  'Beyond the Black Rainbow',
#  'The Jacket',
#  '10 Things I Hate About You',
#  'Dry Spell',
#  'Facing the Giants',
#  'The Manchurian Candidate',
#  'The Perez Family',
#  'The Visit',
#  'Indiana Jones and the Temple of Doom',
#  'Arbitrage',
#  'The Good Girl',
#  'Brooklyn Rules',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Bats',
#  'Aquamarine',
#  'My Name Is Bruce',
#  'Taking Woodstock',
#  'The Jungle Book 2',
#  'Highlander',
#  'My Life in Ruins',
#  'Monsters vs Aliens',
#  'Due Date',
#  'The Wild Bunch',
#  'The Wizard of Oz',
#  'Damsels in Distress',
#  'Turbo',
#  'The Sisterhood of the Traveling Pants 2',
#  'Baby Geniuses',
#  'Aberdeen',
#  'How to Lose Friends & Alienate People',
#  'Happy Feet',
#  'Bolt',
#  'The Lake House',
#  'At First Sight',
#  'Nothing But a Man',
#  'Yes',
#  'The Dead Undead',
#  'Martian Child',
#  'Mirrormask',
#  'Megamind',
#  'The Little Prince',
#  'Dolphins and Whales: Tribes of the Ocean',
#  'House at the End of the Drive',
#  'Pulp Fiction',
#  'The Simpsons Movie',
#  'No Country for Old Men',
#  '16 Blocks',
#  'Identity',
#  'Butterfly on a Wheel',
#  'The Ninth Gate',
#  'Iraq for Sale: The War Profiteers',
#  'Tracker',
#  'Far from Heaven',
#  'Wicked Blood',
#  'The Adventures of Elmo in Grouchland',
#  'G.I. Joe: Retaliation',
#  'Open Water',
#  'Death at a Funeral',
#  'Congo',
#  'Fat Albert',
#  'Wuthering Heights',
#  'Ransom',
#  'A Haunted House 2',
#  'Shrek Forever After',
#  'The Spectacular Now',
#  'Trouble with the Curve',
#  'Gone in Sixty Seconds',
#  'Jack Ryan: Shadow Recruit',
#  'Two Can Play That Game',
#  'Pitch Black',
#  'Evil Dead',
#  'Fighting Tommy Riley',
#  'Legend of a Rabbit',
#  'The Hadza:  Last of the First',
#  'Office Space',
#  'Terminator Salvation',
#  'Hatchet',
#  'Road Hard',
#  'The Final Destination',
#  'The Right Stuff',
#  'Stoker',
#  'Superman IV: The Quest for Peace',
#  'Autumn in New York',
#  'The Messenger',
#  'Ultraviolet',
#  'Transformers: Age of Extinction',
#  'The Yards',
#  'The Kentucky Fried Movie',
#  'Annabelle',
#  'Bedazzled',
#  'Driven',
#  'The Hammer',
#  'Red Planet',
#  'Ghost Rider',
#  'Sands of Iwo Jima',
#  'Cool Runnings',
#  'Braveheart',
#  'Full Frontal',
#  'Im Not There.',
#  'The Dangerous Lives of Altar Boys',
#  'Trucker',
#  'Dear Wendy',
#  'Lifeforce',
#  'Bachelorette',
#  '90 Minutes in Heaven',
#  'Bamboozled',
#  'Public Enemies',
#  'Slacker Uprising',
#  'Race',
#  'The Untouchables',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Born Of War',
#  'Changing Lanes',
#  '3:10 to Yuma',
#  'Being John Malkovich',
#  'Julie & Julia',
#  'Return to the Blue Lagoon',
#  'The Night Listener',
#  'Unforgiven',
#  'The Brothers',
#  'The Spy Next Door',
#  'Sex Tape',
#  'Paul',
#  'Johnson Family Vacation',
#  'Warm Bodies',
#  'Code of Honor',
#  'The Perfect Host',
#  'Kangaroo Jack',
#  'Scoop',
#  'Unfinished Business',
#  'Herbie Fully Loaded',
#  'Bowfinger',
#  'Get Over It',
#  'The Sessions',
#  'Regression',
#  'Instinct',
#  'Die Another Day',
#  'Harold & Kumar Go to White Castle',
#  'The Lord of the Rings: The Return of the King',
#  'Shame',
#  'Talk Radio',
#  'Elektra',
#  'The Whole Ten Yards',
#  'Groove',
#  'The Baader Meinhof Complex',
#  'Harry Potter and the Goblet of Fire',
#  'From Here to Eternity',
#  'Yesterday Was a Lie',
#  'How to Train Your Dragon',
#  'Ex Machina',
#  'Black Swan',
#  'Extremely Loud & Incredibly Close',
#  'The Big Hit',
#  'Boogie Nights',
#  'Hands of Stone',
#  'Motherhood',
#  'Old Dogs',
#  'Shark Lake',
#  'Son of God',
#  'Quigley Down Under',
#  'Three to Tango',
#  'Animal House',
#  'The Long Riders',
#  'Life as a House',
#  'Shadowlands',
#  'Secretariat',
#  'Guardians of the Galaxy',
#  'Straightheads',
#  'Tumbleweeds',
#  'Police Academy: Mission to Moscow',
#  'When Harry Met Sally...',
#  'Batman Begins',
#  'Stitches',
#  'Tower Heist',
#  'Shade',
#  'The Deer Hunter',
#  'The Game Plan',
#  'Goodbye Bafana',
#  'The Damned United',
#  'Point Blank',
#  'Centurion',
#  'Jurassic Park',
#  'The Beyond',
#  'Queen Crab',
#  'Boat Trip',
#  'Oblivion',
#  'The Grudge',
#  'The Ridiculous 6',
#  'Skyline',
#  'The Other Boleyn Girl',
#  'The Horse Boy',
#  'Mad Max: Fury Road',
#  'The Haunted Mansion',
#  'The Huntsman: Winters War',
#  'Teeth and Blood',
#  'Ghosts of Mars',
#  'Precious',
#  'Arlington Road',
#  'The Lost Boys',
#  'The Mudge Boy',
#  'Howards End',
#  'A Nightmare on Elm Street 4: The Dream Master',
#  'Cliffhanger',
#  'Deliver Us from Evil',
#  'Godsend',
#  'Water for Elephants',
#  'Little Voice',
#  'The Life Before Her Eyes',
#  '21 Jump Street',
#  'Roll Bounce',
#  'I Love You, Dont Touch Me!',
#  'Street Fighter',
#  'The Purge: Anarchy',
#  '8 Mile',
#  'The Internship',
#  'V for Vendetta',
#  'Whatever It Takes',
#  'Prom',
#  'Bullet to the Head',
#  'The Skeleton Key',
#  'The Young Unknowns',
#  'The Color Purple',
#  'Mad Max',
#  'Fantastic Four',
#  'Lincoln',
#  'Slow Burn',
#  'Brighton Rock',
#  'The Christmas Candle',
#  'My Soul to Take',
#  'Scott Pilgrim vs. the World',
#  'Jack the Giant Slayer',
#  'Australia',
#  'Scary Movie 5',
#  'Fuel',
#  'Chicken Little',
#  'Jade',
#  'The Green Hornet',
#  'The Killer Inside Me',
#  'The Lion King',
#  'The Lost Weekend',
#  'From Hell',
#  'Top Hat',
#  'Step Brothers',
#  'The Great Raid',
#  'Love in the Time of Cholera',
#  'Marie Antoinette',
#  'Antiviral',
#  'Last Holiday',
#  'Edtv',
#  'The Wicked Lady',
#  'Welcome to the Rileys',
#  'The Longest Yard',
#  'When Did You Last See Your Father?',
#  'Stargate: The Ark of Truth',
#  'Click',
#  'Woman Thou Art Loosed',
#  'Plush',
#  'Repo Men',
#  '3000 Miles to Graceland',
#  'Step Up 3D',
#  'Intolerance',
#  'About Schmidt',
#  'Major League',
#  'Mulan',
#  'Charlie and the Chocolate Factory',
#  'Memento',
#  'The Quiet American',
#  'Kung Fu Panda 2',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'O Brother, Where Art Thou?',
#  'The Hurt Locker',
#  'Thirteen Days',
#  'Licence to Kill',
#  'The Perfect Man',
#  'Dreaming of Joseph Lees',
#  'Carnage',
#  'Funny Games',
#  'Suicide Squad',
#  'Glitter',
#  'Sense and Sensibility',
#  'The Pianist',
#  'Soul Surfer',
#  'United 93',
#  'Independence Day: Resurgence',
#  'The Game of Their Lives',
#  'The Lawnmower Man',
#  'Friday the 13th Part III',
#  'The Day After Tomorrow',
#  'American Pie',
#  'Sex, Lies, and Videotape',
#  'Timecop',
#  'Body Double',
#  'Curious George',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Nowhere to Run',
#  'Someone Like You...',
#  'The Darkest Hour',
#  'Fight to the Finish',
#  'Made of Honor',
#  'Cop Out',
#  'Monster',
#  'Superbad',
#  'The Great Gatsby',
#  'Total Recall',
#  'Shutter Island',
#  'Poohs Heffalump Movie',
#  'Unleashed',
#  'Chloe',
#  'How to Deal',
#  'Legion',
#  'I, Frankenstein',
#  'The Other Dream Team',
#  'Angel Eyes',
#  'The Kite Runner',
#  'The Forest',
#  'Monsters, Inc.',
#  'Nighthawks',
#  'Veronica Guerin',
#  'George of the Jungle',
#  'Get Low',
#  'As It Is in Heaven',
#  'The First Wives Club',
#  'Elysium',
#  '28 Weeks Later',
#  'Pocketful of Miracles',
#  'Disaster Movie',
#  'Echo Dr.',
#  'Married Life',
#  'Panic Room',
#  'Poultrygeist: Night of the Chicken Dead',
#  'Star Trek VI: The Undiscovered Country',
#  'Dear John',
#  'Troop Beverly Hills',
#  'Warrior',
#  'Footloose',
#  'Les Misérables',
#  'Out of the Furnace',
#  'Da Sweet Blood of Jesus',
#  'Harsh Times',
#  'Rampage',
#  'The 6th Day',
#  'Maniac',
#  'Annie',
#  'Street Kings',
#  'Hav Plenty',
#  'Eraserhead',
#  'Songcatcher',
#  'Ca$h',
#  'A Very Harold & Kumar Christmas',
#  'Big Mommas House',
#  'To Kill a Mockingbird',
#  'Sorcerer',
#  'Ordinary People',
#  'Kites',
#  'Prophecy',
#  'License to Wed',
#  'San Andreas',
#  'Stranded',
#  'Transformers: Revenge of the Fallen',
#  'The Last Samurai',
#  'Black or White',
#  'Buffalo Soldiers',
#  'The Reader',
#  'The Fog',
#  'Americas Sweethearts',
#  'The Spiderwick Chronicles',
#  'The Stepfather',
#  'Interview with the Vampire',
#  'The To Do List',
#  'Dirty Grandpa',
#  'Cant Hardly Wait',
#  'Inside Man',
#  'Abandoned',
#  'Antarctic Edge: 70° South',
#  'Escape from Tomorrow',
#  'An Everlasting Piece',
#  'Left Behind',
#  'New York Stories',
#  'Bad Words',
#  'In the Name of the King III',
#  'After Earth',
#  'Dr. Dolittle 2',
#  'Annie Get Your Gun',
#  'Dark Water',
#  'Modern Times',
#  'Duma',
#  'The Three Musketeers',
#  'Lucky Numbers',
#  'First Knight',
#  'The Holiday',
#  'Envy',
#  'The Adjustment Bureau',
#  'Gentlemans Agreement',
#  'Jersey Girl',
#  'Mission: Impossible II',
#  'Liar Liar',
#  'Another Year',
#  'Beverly Hills Cop II',
#  'Rockaway',
#  'Miss Congeniality',
#  'The Incredible Burt Wonderstone',
#  'Any Given Sunday',
#  'An Unfinished Life',
#  'Clockwatchers',
#  'Stolen Summer',
#  'Topsy-Turvy',
#  'Don Juan DeMarco',
#  'Need for Speed',
#  'Double Jeopardy',
#  'Tomorrowland',
#  'Young Adult',
#  'De-Lovely',
#  'Kids',
#  'Bobby',
#  'I Know What You Did Last Summer',
#  'Bully',
#  'The Scorpion King',
#  'Love Actually',
#  'The Addams Family',
#  'Dead Man Down',
#  'Deceptive Practice: The Mysteries and Mentors of Ricky Jay',
#  'Dancer in the Dark',
#  'Horrible Bosses',
#  'The Campaign',
#  'The Witch',
#  'The Three Burials of Melquiades Estrada',
#  'Blue Jasmine',
#  'Antitrust',
#  'Song One',
#  'The Hours',
#  'Shrek',
#  'A Perfect Getaway',
#  'Redemption Road',
#  'Our Brand Is Crisis',
#  'The Astronaut Farmer',
#  'Going the Distance',
#  'White Noise 2: The Light',
#  'Air Force One',
#  'Dogtown and Z-Boys',
#  'Nutty Professor II: The Klumps',
#  'Star Wars: Episode II - Attack of the Clones',
#  'The Blair Witch Project',
#  'The Flintstones in Viva Rock Vegas',
#  'The Rugrats Movie',
#  'Fireproof',
#  'The Savages',
#  '54',
#  'The Bourne Legacy',
#  'Face/Off',
#  'Tombstone',
#  'The Smurfs',
#  'Beverly Hills Cop III',
#  'Pitch Perfect 2',
#  'Whatever Works',
#  'Club Dread',
#  'Hobo with a Shotgun',
#  'Six-String Samurai',
#  'I, Robot',
#  'Death Becomes Her',
#  'Frat Party',
#  'Swimfan',
#  'Thr3e',
#  'Mama',
#  'Salvador',
#  'Signs',
#  'Aliens in the Attic',
#  'I Got the Hook Up',
#  'Dead Like Me: Life After Death',
#  'Paranormal Activity 4',
#  'Ever After: A Cinderella Story',
#  'The Blue Bird',
#  'Escape from New York',
#  'The Veil',
#  'Gangster Squad',
#  'Coraline',
#  'You Dont Mess with the Zohan',
#  'The Best Offer',
#  'Crank',
#  'Promised Land',
#  'The Duchess',
#  'The Trouble with Harry',
#  'The Social Network',
#  'Barnyard',
#  'Chasing Papi',
#  'Battle for the Planet of the Apes',
#  'Night at the Museum',
#  'Cop Land',
#  'Krush Groove',
#  'Love Happens',
#  'The Covenant',
#  'Housebound',
#  'Mommie Dearest',
#  'Star Trek',
#  'Charlie Bartlett',
#  'The Blue Lagoon',
#  'Janky Promoters',
#  'Novocaine',
#  'Random Hearts',
#  'Richard III',
#  'X-Men: The Last Stand',
#  'Good Intentions',
#  'The Thief and the Cobbler',
#  'Growing Up Smith',
#  'Saving Face',
#  'The Men Who Stare at Goats',
#  'Boynton Beach Club',
#  'Ishtar',
#  'Tank Girl',
#  'Flyboys',
#  'Piranha 3D',
#  'You Only Live Twice',
#  'The Smurfs 2',
#  'Kicks',
#  'August Rush',
#  'Tucker and Dale vs Evil',
#  'The Hangover Part II',
#  'A History of Violence',
#  'Darling Companion',
#  'Vanilla Sky',
#  'Ice Age: Continental Drift',
#  '10 Days in a Madhouse',
#  'Logans Run',
#  'Seven Pounds',
#  'Duets',
#  'The Mask of Zorro',
#  'Scary Movie 3',
#  'Woman in Gold',
#  'Home Alone 2: Lost in New York',
#  'City Island',
#  'Sydney White',
#  'The Edge',
#  'White House Down',
#  'The Man Who Shot Liberty Valance',
#  'Earth to Echo',
#  'Wild Things',
#  'Hotel Transylvania',
#  'The 51st State',
#  'Bambi',
#  'Zoom',
#  'TRON: Legacy',
#  'South Park: Bigger, Longer & Uncut',
#  'The Big Year',
#  'An American Carol',
#  'Boyz n the Hood',
#  'Warlock',
#  'Mr. Smith Goes to Washington',
#  'Jackie Brown',
#  'Survivor',
#  'Twins',
#  'Tarnation',
#  'The Time Travelers Wife',
#  'Bulworth',
#  'Simon Birch',
#  'Home Run',
#  'Dream House',
#  'Charlottes Web',
#  'The Abyss',
#  'Garden State',
#  'Scream 3',
#  'Forbidden Kingdom',
#  'Harry Potter and the Order of the Phoenix',
#  'Out of Time',
#  'The Fault in Our Stars',
#  '20,000 Leagues Under the Sea',
#  'Slow West',
#  'The Valley of Decision',
#  'The Players Club',
#  'Infamous',
#  'Marvins Room',
#  'Next Day Air',
#  'The Rage: Carrie 2',
#  'The In Crowd',
#  'North Country',
#  'The Tree of Life',
#  'Meeks Cutoff',
#  'Nebraska',
#  'Disturbia',
#  'Gods and Monsters',
#  'Down to You',
#  'Definitely, Maybe',
#  'My Dog Tulip',
#  'The Worlds Fastest Indian',
#  'The Night Visitor',
#  'Idle Hands',
#  'I Love You Phillip Morris',
#  'Lion of the Desert',
#  'No Reservations',
#  'Magic Mike',
#  'In Cold Blood',
#  'The Sound of Music',
#  'Wal-Mart: The High Cost of Low Price',
#  'Gunless',
#  'The Secret Life of Walter Mitty',
#  'Half Baked',
#  'Session 9',
#  '1941',
#  'Beneath Hill 60',
#  'Meet Dave',
#  'The Benchwarmers',
#  'Maurice',
#  'The Wackness',
#  'Admission',
#  'Valentine',
#  'Circumstance',
#  'Sheena',
#  'The Terminator',
#  'Lonesome Jim',
#  '8MM',
#  'The Red Violin',
#  'Analyze This',
#  'The River Wild',
#  'Saw: The Final Chapter',
#  'The Five-Year Engagement',
#  'Enough',
#  'Hes Just Not That Into You',
#  'Payback',
#  'Action Jackson',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'Close Range',
#  'The Misfits',
#  'Trance',
#  'Never Again',
#  'DragonHeart',
#  '21 & Over',
#  'In the Heart of the Sea',
#  'No Mans Land: The Rise of Reeker',
#  'Screwed',
#  'The Expendables 2',
#  'The Odd Life of Timothy Green',
#  'Whats Eating Gilbert Grape',
#  'Beastly',
#  'Delgo',
#  'Eragon',
#  'Killing Zoe',
#  'Good',
#  'Keanu',
#  'Shanghai Calling',
#  'Miss Potter',
#  'The Indian in the Cupboard',
#  'Star Trek Beyond',
#  'Love Letters',
#  'Inside Llewyn Davis',
#  'Hoodwinked!',
#  'Rambo III',
#  'Slackers',
#  'The Legend of Hercules',
#  'Topaz',
#  'A Sound of Thunder',
#  'Highlander: The Final Dimension',
#  'The Big Bounce',
#  'Cypher',
#  'The Nutty Professor',
#  'I Am Sam',
#  'Cloudy with a Chance of Meatballs 2',
#  'Pay It Forward',
#  'The Bad News Bears',
#  'Under the Rainbow',
#  'Leaving Las Vegas',
#  'Hey Arnold! The Movie',
#  'Submarine',
#  'Days of Heaven',
#  'The Informant!',
#  'Censored Voices',
#  'Ask Me Anything',
#  'L.I.E.',
#  'Red Tails',
#  'The Rise of the Krays',
#  'Lesbian Vampire Killers',
#  'The Last Exorcism Part II',
#  'Jason Goes to Hell: The Final Friday',
#  'Final Destination',
#  'Remember Me, My Love',
#  'The World Is Not Enough',
#  'Soul Men',
#  'Exorcist II: The Heretic',
#  'Hanna',
#  'Deadpool',
#  'Observe and Report',
#  'The Clan of the Cave Bear',
#  'Flawless',
#  'Blood Work',
#  'Youve Got Mail',
#  'American Splendor',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'The Spy Who Loved Me',
#  'Chain Letter',
#  'Tuck Everlasting',
#  'Get Carter',
#  'The Maids Room',
#  'From Justin to Kelly',
#  'Moms Night Out',
#  'A Guy Thing',
#  'Heartbeeps',
#  'Eulogy',
#  'Gentlemen Broncos',
#  'Give Me Shelter',
#  'Everything Must Go',
#  'American Heist',
#  'Felicias Journey',
#  'The Last Waltz',
#  'Bulletproof Monk',
#  'The New Guy',
#  'Catch That Kid',
#  'Underworld: Rise of the Lycans',
#  'Insidious: Chapter 3',
#  'Slacker',
#  'Wrong Turn',
#  'I Spy',
#  'Not Easily Broken',
#  'Flash of Genius',
#  'Texas Chainsaw 3D',
#  'Still Alice',
#  'The Boss',
#  'Let Me In',
#  'Confidence',
#  'Half Past Dead',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Wall Street: Money Never Sleeps',
#  'Pokémon: Spell of the Unknown',
#  'The Conversation',
#  'The Work and the Glory II: American Zion',
#  'Safe Haven',
#  'Serenity',
#  'Domino',
#  'The Other Guys',
#  '8: The Mormon Proposition',
#  'D-Tox',
#  'Dear Frankie',
#  'The Ring Two',
#  'Inside Out',
#  'Shadow of the Vampire',
#  'American Beast',
#  'Maos Last Dancer',
#  'Austin Powers in Goldmember',
#  'Jupiter Ascending',
#  'Barneys Great Adventure',
#  'The Amazing Spider-Man 2',
#  'Escape Plan',
#  'The Express',
#  'Tin Can Man',
#  'Savage Grace',
#  'Little Black Book',
#  'The Help',
#  'Friends with Money',
#  'Monster House',
#  'Trainspotting',
#  'Addicted',
#  'Beautiful Creatures',
#  'My Bloody Valentine',
#  'Hocus Pocus',
#  'Mr. Deeds',
#  'Grosse Pointe Blank',
#  'Lakeview Terrace',
#  'Psycho',
#  'Harry Potter and the Half-Blood Prince',
#  'Déjà Vu',
#  'Remember Me',
#  'The Black Hole',
#  'Crocodile Dundee in Los Angeles',
#  'Never Say Never Again',
#  'The Thirteenth Floor',
#  'Why Did I Get Married Too?',
#  'Jackass: The Movie',
#  'Reno 911!: Miami',
#  'Broken Arrow',
#  'Cabin Fever',
#  'The Equalizer',
#  'The Walking Deceased',
#  'Chasing Liberty',
#  'Feast',
#  'Jack Reacher',
#  'The Kings Speech',
#  'Where the Wild Things Are',
#  'Falcon Rising',
#  'Wish I Was Here',
#  'Where the Truth Lies',
#  'Pirates of the Caribbean: Dead Mans Chest',
#  'The Da Vinci Code',
#  'Legal Eagles',
#  'The Second Best Exotic Marigold Hotel',
#  'Buffalo 66',
#  'The Net',
#  'Home for the Holidays',
#  'Triangle',
#  'The Lovely Bones',
#  'Rosewater',
#  'Gandhi',
#  'Heavy Metal',
#  'Silent Running',
#  'Double Impact',
#  'The Man from Earth',
#  'Old Joy',
#  'Patch Adams',
#  'The Cavemans Valentine',
#  'Chicken Run',
#  '300: Rise of an Empire',
#  'Mary Poppins',
#  'Lilo & Stitch',
#  'The Ladykillers',
#  'Scooby-Doo',
#  'Angelas Ashes',
#  'Dope',
#  'John Q',
#  'Red Dawn',
#  'Jakob the Liar',
#  'The Godfather',
#  'Enders Game',
#  'Disclosure',
#  'Agora',
#  'The Act of Killing',
#  'Spellbound',
#  'Days of Thunder',
#  'The Broadway Melody',
#  'Southpaw',
#  'A Beginners Guide to Snuff',
#  'Shine',
#  'Star Trek: The Motion Picture',
#  'Monsters Ball',
#  'Lost in Space',
#  'The Libertine',
#  'Abraham Lincoln: Vampire Hunter',
#  'The Core',
#  'Queen of the Damned',
#  'Teenage Mutant Ninja Turtles',
#  'Auto Focus',
#  '3 Ninjas Kick Back',
#  'Subconscious',
#  'Ella Enchanted',
#  'A Simple Wish',
#  'Chairman of the Board',
#  'Final Destination 5',
#  'Drillbit Taylor',
#  'Gods Not Dead 2',
#  'Edmond',
#  'Beverly Hills Cop',
#  'Deep Impact',
#  'After.Life',
#  'Dark City',
#  'Riding in Cars with Boys',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Mr. Beans Holiday',
#  'The Great Escape',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Small Soldiers',
#  'Mystic Pizza',
#  'The Other Woman',
#  'War, Inc.',
#  'Bathing Beauty',
#  'LOL',
#  'Requiem for a Dream',
#  '2:13',
#  'Celebrity',
#  'Fever Pitch',
#  'Inside Deep Throat',
#  'Amen.',
#  'Re-Kill',
#  'Sarahs Key',
#  'Gods and Generals',
#  'Babe',
#  'Kung Fu Panda',
#  'Universal Soldier: The Return',
#  'Exotica',
#  'The Bridge of San Luis Rey',
#  'Under the Skin',
#  'Lolita',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'The Lion of Judah',
#  'Couples Retreat',
#  'Live Free or Die Hard',
#  'Sahara',
#  'The Crow',
#  'John Carter',
#  'Beloved',
#  'The Wolverine',
#  'Saw III',
#  'American Hero',
#  'Mickey Blue Eyes',
#  'Mindhunters',
#  'End of the Spear',
#  'A Good Day to Die Hard',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Shadow Conspiracy',
#  'Deterrence',
#  'Shes Gotta Have It',
#  'The Best Man',
#  '20 Dates',
#  'Drive Hard',
#  'Fifty Dead Men Walking',
#  'Spy Kids 3-D: Game Over',
#  'National Lampoon’s Van Wilder',
#  'The Big Short',
#  'Limbo',
#  'The Mechanic',
#  'War of the Worlds',
#  'Paranormal Activity: The Marked Ones',
#  'Trade Of Innocents',
#  'Barry Munday',
#  'Me Before You',
#  'The Master of Disguise',
#  'The Divide',
#  'Mutual Friends',
#  'WarGames',
#  'Diary of a Mad Black Woman',
#  'Born to Fly: Elizabeth Streb vs. Gravity',
#  'Show Boat',
#  'Iris',
#  'This Means War',
#  'Stuart Little 2',
#  'Hard Rain',
#  'The Nuns Story',
#  'Among Giants',
#  'The Warriors Way',
#  'Top Gun',
#  'New Nightmare',
#  'The Fast and the Furious',
#  'Outbreak',
#  'Shopgirl',
#  'Never Let Me Go',
#  'Dark Blue',
#  'Hitch',
#  'Secretary',
#  'The Fan',
#  'Little Nicky',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'A Madea Christmas',
#  'The Road to El Dorado',
#  'Hang em High',
#  'The Oh in Ohio',
#  'Creepshow',
#  'Die Hard 2',
#  'F.I.S.T.',
#  'The Pursuit of D.B. Cooper',
#  'Chappie',
#  'In Bruges',
#  'Things We Lost in the Fire',
#  'Wont Back Down',
#  'Message in a Bottle',
#  'Open Season',
#  'A Walk on the Moon',
#  'Bound',
#  'Original Sin',
#  'The Apostle',
#  'The Cold Light of Day',
#  'The Art of Getting By',
#  'The Tourist',
#  'Theres Always Woodstock',
#  'Birth',
#  'Big Fish',
#  'Galaxina',
#  'Men in Black II',
#  'Clash of the Titans',
#  'Frailty',
#  'The League of Extraordinary Gentlemen',
#  'The Pacifier',
#  'Hollywood Shuffle',
#  'The Verdict',
#  'Hollywood Homicide',
#  'Little Children',
#  'Once',
#  'Shallow Hal',
#  'True Grit',
#  'Hit & Run',
#  'The Little Vampire',
#  'The Visual Bible: The Gospel of John',
#  '1982',
#  'Austin Powers: International Man of Mystery',
#  'The Ant Bully',
#  'Untraceable',
#  '2012',
#  'R.L. Stines Monsterville: The Cabinet of Souls',
#  'Don McKay',
#  'Amistad',
#  'Maggie',
#  'Star Trek II: The Wrath of Khan',
#  'Just Like Heaven',
#  'My Best Friends Girl',
#  'Terminator 3: Rise of the Machines',
#  'Independence Daysaster',
#  'The Jerky Boys',
#  'The Calling',
#  'Dave Chappelles Block Party',
#  'Bringing Out the Dead',
#  'Firewall',
#  'Friends with Benefits',
#  'Childless',
#  'Super',
#  'The Longshots',
#  'A League of Their Own',
#  'Christmas Mail',
#  'Rize',
#  'All Hat',
#  ...]

# %%
prolog.assertz('''(black_and_white(X, Y):-
 plot_keywords(X, 'black and white'), plot_keywords(Y, 'black and white'), X \= Y)''')

# %% [markdown]
# Προσθήκη κατηγορήματος για έγχρωμες ή ασπρόμαυρες ταινίες.

# %%
def black_and_white(movie):
  q = prolog.query("black_and_white('" + movie + "', M)")
  ans = []
  for soln in q:
      ans.append(soln["M"])
  if len(ans) > 0:
   return ("This movie is black and white")
  else: 
    return ("This movie is in color")

# %%
black_and_white("The Phantom of the Opera")
# Out:
# 'This movie is black and white'

# %% [markdown]
# Υλοποιήθηκε και το common colour το οποίο χρησιμοποιήθηκε στο δεύτερο μέρος

# %%
prolog.assertz('(common_col(X, Y) :- color(X, A), color(Y, A), X \= Y )')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινό χρώμα

# %%
def common_col(movie):
    q = prolog.query("common_col('" + movie +"',M)")
    ans = []
    for soln in q:
        ans.append(soln["M"])
    return list(set(ans))

# %%
common_col("The Phantom of the Opera")
# Out:
# ['Frances Ha', 'The Giver', 'Renaissance', 'Frankenweenie', 'Creative Control']

# %%
prolog.assertz('''(same_production(X, Y):-
  production_companies(X, F, L),
  production_companies(Y, F, L), X \= Y)''')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινή παραγωγή

# %%
def same_production(movie):
  q = prolog.query("same_production('" + movie + "', M)")
  ans = []
  for soln in q:
      ans.append(soln["M"])
  return list(set(ans))

# %%
same_production("Avatar")
# Out:
# ['Planet of the Apes',
#  'Garfield',
#  'Dragonball Evolution',
#  'Kung Fu Panda 3',
#  'Road to Perdition',
#  'Welcome to Mooseport',
#  'Conquest of the Planet of the Apes',
#  'Hitman',
#  'Big Mommas: Like Father, Like Son',
#  'DodgeBall: A True Underdog Story',
#  'Flyboys',
#  'Jumper',
#  'All That Jazz',
#  'Taken 3',
#  'Doctor Dolittle',
#  'The X Files',
#  'The Legend of Bagger Vance',
#  'The Golden Compass',
#  'Dude, Where’s My Car?',
#  'Percy Jackson: Sea of Monsters',
#  'The Day the Earth Stood Still',
#  'Aliens vs Predator: Requiem',
#  'Home Alone 2: Lost in New York',
#  'Hoffa',
#  'Alatriste',
#  'The Rose',
#  'Young Guns',
#  'Monte Carlo',
#  'Speed 2: Cruise Control',
#  'Knight and Day',
#  'Brokedown Palace',
#  'Alexanders Ragtime Band',
#  'Our Family Wedding',
#  'Babys Day Out',
#  'Cleopatra',
#  'Kung Pow: Enter the Fist',
#  'Star Wars',
#  'Taken',
#  'The Big Year',
#  'Suicide Squad',
#  'Stardust',
#  'Hide and Seek',
#  'Glitter',
#  'Grandmas Boy',
#  'History of the World: Part I',
#  'Virgin Territory',
#  'Predators',
#  'Independence Day: Resurgence',
#  'Bulworth',
#  'The Conjuring 2',
#  'Edward Scissorhands',
#  'Titan A.E.',
#  'The Day After Tomorrow',
#  'The Heat',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'The Abyss',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Taken 2',
#  'Vera Drake',
#  'Lets Be Cops',
#  'Say It Isnt So',
#  'The Passion of the Christ',
#  'Abraham Lincoln: Vampire Hunter',
#  'Hope Floats',
#  'Patton',
#  'Kingdom of Heaven',
#  'The Egyptian',
#  'The Simpsons Movie',
#  'Transporter 2',
#  'X-Men',
#  'Hairspray',
#  'Cheaper by the Dozen',
#  'Commando',
#  'The Book of Life',
#  'Life of Pi',
#  'Fantastic Mr. Fox',
#  'Niagara',
#  'Big Trouble in Little China',
#  'Like Mike',
#  'Victor Frankenstein',
#  'Chronicle',
#  'Post Grad',
#  'Young Frankenstein',
#  'High Crimes',
#  'Prometheus',
#  'Jingle All the Way',
#  'The Hustler',
#  'Fat Albert',
#  'Home',
#  'Anywhere But Here',
#  'Moulin Rouge!',
#  'The Other Woman',
#  'Volcano',
#  'The Happening',
#  'Titanic',
#  'Garfield: A Tail of Two Kitties',
#  'Die Hard',
#  'The Sound of Music',
#  'The Watch',
#  'The Secret Life of Walter Mitty',
#  'Love & Other Drugs',
#  'Meet Dave',
#  'Predator',
#  'Office Space',
#  'What Lies Beneath',
#  'Black Knight',
#  'The Siege',
#  'AVP: Alien vs. Predator',
#  'Home Alone',
#  'How Stella Got Her Groove Back',
#  'Kiss of the Dragon',
#  'Notes on a Scandal',
#  'Live Free or Die Hard',
#  'Bedazzled',
#  'Love Me Tender',
#  'X-Men Origins: Wolverine',
#  'Drive Me Crazy',
#  'Gullivers Travels',
#  'The Omen',
#  'Rise of the Planet of the Apes',
#  'The Wolverine',
#  'Mrs. Doubtfire',
#  'Tora! Tora! Tora!',
#  'Aliens',
#  'Die Hard: With a Vengeance',
#  'Marmaduke',
#  'A Good Day to Die Hard',
#  'Parental Guidance',
#  'Beneath the Planet of the Apes',
#  'Big Mommas House',
#  'I Love You, Beth Cooper',
#  'Chain Reaction',
#  'Eragon',
#  'What Happens in Vegas',
#  '20 Dates',
#  'Whip It',
#  'Fantastic 4: Rise of the Silver Surfer',
#  'Devils Due',
#  'Monkeybone',
#  'Big',
#  'Kiss of Death',
#  'Death Sentence',
#  'Alien',
#  'Me, Myself & Irene',
#  'Scoop',
#  'Mr. Poppers Penguins',
#  'Butch Cassidy and the Sundance Kid',
#  'Brick Lane',
#  'Dr. Dolittle 2',
#  'Predator 2',
#  'The Adventures of Ford Fairlane',
#  'Night at the Museum: Secret of the Tomb',
#  'The Martian',
#  'The Maze Runner',
#  'This Means War',
#  'Gentlemans Agreement',
#  'Street Fighter: The Legend of Chun-Li',
#  'The Object of My Affection',
#  'The Hills Have Eyes 2',
#  'Damnation Alley',
#  'Elektra',
#  'Red Tails',
#  'That Thing You Do!',
#  'The Marine',
#  'Alien: Resurrection',
#  'The Full Monty',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  'Paparazzi',
#  'Terminator 2: Judgment Day',
#  'Black Swan',
#  'Deadpool',
#  'Eddie the Eagle',
#  'Unstoppable',
#  'The Hills Have Eyes',
#  'Escape from the Planet of the Apes',
#  'Cast Away',
#  'Die Hard 2',
#  'Jennifers Body',
#  'Alien³',
#  'The Newton Boys',
#  'Flicka',
#  'Wall Street',
#  'Anastasia',
#  'Straightheads',
#  'The Robe',
#  'The Order',
#  'Master and Commander: The Far Side of the World',
#  'The Devil Wears Prada',
#  'Beyond the Valley of the Dolls',
#  'Behind Enemy Lines',
#  'Ladyhawke',
#  'The Empire Strikes Back',
#  'The League of Extraordinary Gentlemen',
#  'True Lies',
#  'The Verdict',
#  'Just Wright',
#  'The French Connection',
#  'All About Steve',
#  'Diary of a Wimpy Kid',
#  'Glee: The Concert Movie',
#  'Wall Street: Money Never Sleeps',
#  'Shallow Hal',
#  'The Sitter',
#  'Sunshine',
#  'The Longest Day',
#  'Gone Girl',
#  'Batman',
#  'Ramona and Beezus',
#  'Water for Elephants',
#  'Flight of the Phoenix',
#  'I, Robot',
#  'We Bought a Zoo',
#  'Hannibal Rising',
#  'High Anxiety',
#  'My Cousin Vinny',
#  'Swimfan',
#  'Minority Report',
#  'Speed',
#  'Julia',
#  'Jupiter Ascending',
#  'Ice Age',
#  'Max Payne',
#  'Aliens in the Attic',
#  'Stuck on You',
#  'The Blue Bird',
#  'The Internship',
#  'Ever After: A Cinderella Story',
#  'Deadline - U.S.A.',
#  'X-Men: Apocalypse',
#  'Independence Day',
#  'Chariots of Fire',
#  'Ravenous',
#  'Date Night',
#  'Romeo + Juliet',
#  'Bride Wars',
#  'X-Men: Days of Future Past',
#  'The X Files: I Want to Believe',
#  'Machete',
#  'Where the Heart Is',
#  'Fantastic Four',
#  'Lincoln',
#  'Big Mommas House 2',
#  'How Green Was My Valley',
#  'Alvin and the Chipmunks',
#  'Australia',
#  'Battle for the Planet of the Apes',
#  'Cheaper by the Dozen 2',
#  'Epic Movie',
#  'Night at the Museum',
#  'State Fair',
#  'The Last Legion',
#  'The Sentinel',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'From Hell',
#  'X2',
#  'X-Men: First Class',
#  'Just Married',
#  'Reno 911!: Miami',
#  'Theres Something About Mary',
#  'Broken Arrow',
#  'Because of Winn-Dixie',
#  'Idiocracy',
#  'Return of the Jedi',
#  'The Descendants',
#  'X-Men: The Last Stand']

# %%
prolog.assertz('''(same_production_country(X, Y):-
  production_countries(X, F, L),
  production_countries(Y, F, L), 
  X \= Y) ''')

# %% [markdown]
# Προσθήκη κατηγορήματος για κοινή χώρα παραγωγής

# %%
def same_production_country(movie):
  q = prolog.query("same_production_country('" + movie + "', M)")
  ans = []
  for soln in q:
      ans.append(soln["M"])
  return list(set(ans))

# %%
same_production_country("Avatar")
# Out:
# ['Conquest of the Planet of the Apes',
#  'Critical Care',
#  'Impostor',
#  'I Want Someone to Eat Cheese With',
#  'Casino Royale',
#  'Exodus: Gods and Kings',
#  'Dolphin Tale 2',
#  'Rocky Balboa',
#  'School of Rock',
#  'The Jacket',
#  '10 Things I Hate About You',
#  'Dry Spell',
#  'Facing the Giants',
#  'The Manchurian Candidate',
#  'The Perez Family',
#  'The Visit',
#  'Indiana Jones and the Temple of Doom',
#  'Arbitrage',
#  'The Good Girl',
#  'Brooklyn Rules',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Bats',
#  'Aquamarine',
#  'My Name Is Bruce',
#  'See Spot Run',
#  'Taking Woodstock',
#  'The Jungle Book 2',
#  'Highlander',
#  'My Life in Ruins',
#  'Monsters vs Aliens',
#  'Due Date',
#  'The Wild Bunch',
#  'Midnight Run',
#  'Damsels in Distress',
#  'The Wizard of Oz',
#  'Turbo',
#  'Ida',
#  'The Sisterhood of the Traveling Pants 2',
#  'Baby Geniuses',
#  'Aberdeen',
#  'How to Lose Friends & Alienate People',
#  'Bolt',
#  'The Lake House',
#  'At First Sight',
#  'Nothing But a Man',
#  'Yes',
#  'Martian Child',
#  'Mirrormask',
#  'Megamind',
#  'Dolphins and Whales: Tribes of the Ocean',
#  'House at the End of the Drive',
#  'Pulp Fiction',
#  'The Simpsons Movie',
#  'No Country for Old Men',
#  '16 Blocks',
#  'Identity',
#  'Butterfly on a Wheel',
#  'Tracker',
#  'Far from Heaven',
#  'Wicked Blood',
#  'The Adventures of Elmo in Grouchland',
#  'The Water Diviner',
#  'G.I. Joe: Retaliation',
#  'Open Water',
#  'Death at a Funeral',
#  '13 Hours: The Secret Soldiers of Benghazi',
#  'Congo',
#  'Fat Albert',
#  'Ransom',
#  'A Haunted House 2',
#  'Shrek Forever After',
#  'The Importance of Being Earnest',
#  'The Spectacular Now',
#  'Rain Man',
#  'Trouble with the Curve',
#  'Gone in Sixty Seconds',
#  'Jack Ryan: Shadow Recruit',
#  'Two Can Play That Game',
#  'Pitch Black',
#  'Evil Dead',
#  'The Hadza:  Last of the First',
#  'Terminator Salvation',
#  'Office Space',
#  'Hatchet',
#  'Road Hard',
#  'The Final Destination',
#  'The Right Stuff',
#  'The Theory of Everything',
#  'Stoker',
#  'Superman IV: The Quest for Peace',
#  'Autumn in New York',
#  'The Messenger',
#  'Ultraviolet',
#  'Transformers: Age of Extinction',
#  'The Best Exotic Marigold Hotel',
#  'The Yards',
#  'The Kentucky Fried Movie',
#  'Annabelle',
#  'Bedazzled',
#  'Driven',
#  'The Hammer',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Red Planet',
#  'Rollerball',
#  'Ghost Rider',
#  'Sands of Iwo Jima',
#  'Cool Runnings',
#  'Braveheart',
#  'Full Frontal',
#  'Im Not There.',
#  'Silent Movie',
#  'The Dangerous Lives of Altar Boys',
#  'Dear Wendy',
#  'Lifeforce',
#  'Bachelorette',
#  '90 Minutes in Heaven',
#  'Bamboozled',
#  'Public Enemies',
#  'Slacker Uprising',
#  'The Untouchables',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Born Of War',
#  'Changing Lanes',
#  '3:10 to Yuma',
#  'Being John Malkovich',
#  'Julie & Julia',
#  'The Night Listener',
#  'Unforgiven',
#  'The Brothers',
#  'The Spy Next Door',
#  'Sex Tape',
#  'Paul',
#  'Johnson Family Vacation',
#  'Code of Honor',
#  'The Perfect Host',
#  'Kangaroo Jack',
#  'Scoop',
#  'Unfinished Business',
#  'Herbie Fully Loaded',
#  'Bowfinger',
#  'Get Over It',
#  'The Sessions',
#  'Instinct',
#  'Die Another Day',
#  'W.',
#  'Harold & Kumar Go to White Castle',
#  'The Lord of the Rings: The Return of the King',
#  'Shame',
#  'Catch a Fire',
#  'Elektra',
#  'Big Eyes',
#  'Talk Radio',
#  'Groove',
#  'The Whole Ten Yards',
#  'Harry Potter and the Goblet of Fire',
#  'From Here to Eternity',
#  'Yesterday Was a Lie',
#  'How to Train Your Dragon',
#  'Ex Machina',
#  'Black Swan',
#  'Extremely Loud & Incredibly Close',
#  'The Big Hit',
#  'Black Snake Moan',
#  'Boogie Nights',
#  'Hands of Stone',
#  'Motherhood',
#  'Old Dogs',
#  'Shark Lake',
#  'Mi America',
#  'Quigley Down Under',
#  'Animal House',
#  'Son of God',
#  'The Long Riders',
#  'Shadowlands',
#  'Life as a House',
#  'Secretariat',
#  'Guardians of the Galaxy',
#  'Straightheads',
#  'Spectre',
#  'Tumbleweeds',
#  'Police Academy: Mission to Moscow',
#  'When Harry Met Sally...',
#  'Batman Begins',
#  'Tower Heist',
#  'My Girl',
#  'Lords of London',
#  'The Deer Hunter',
#  'Shade',
#  'The Game Plan',
#  'The Damned United',
#  'Point Blank',
#  'Centurion',
#  'Jurassic Park',
#  'Queen Crab',
#  'Boat Trip',
#  'Oblivion',
#  'The Brave Little Toaster',
#  'The Grudge',
#  'The Ridiculous 6',
#  'Skyline',
#  'The Other Boleyn Girl',
#  'Mad Max: Fury Road',
#  'The Haunted Mansion',
#  'Awake',
#  'The Huntsman: Winters War',
#  'Ghosts of Mars',
#  'Precious',
#  'Arlington Road',
#  'The Lost Boys',
#  'The Mudge Boy',
#  'The Story of Us',
#  'Howards End',
#  'A Nightmare on Elm Street 4: The Dream Master',
#  'Cliffhanger',
#  'Deliver Us from Evil',
#  'Godsend',
#  'Water for Elephants',
#  'Little Voice',
#  'The Life Before Her Eyes',
#  '21 Jump Street',
#  'Roll Bounce',
#  'I Love You, Dont Touch Me!',
#  'Street Fighter',
#  'The Purge: Anarchy',
#  'Darling Lili',
#  '8 Mile',
#  'Mean Girls',
#  'The Internship',
#  'V for Vendetta',
#  'Whatever It Takes',
#  'Prom',
#  'Bullet to the Head',
#  'The Skeleton Key',
#  'The Color Purple',
#  'Fantastic Four',
#  'Lincoln',
#  'Slow Burn',
#  'Brighton Rock',
#  'The Christmas Candle',
#  'My Soul to Take',
#  'Scott Pilgrim vs. the World',
#  'Deuce Bigalow: European Gigolo',
#  'Jack the Giant Slayer',
#  'Australia',
#  'Scary Movie 5',
#  'Fuel',
#  'Chicken Little',
#  'Jade',
#  'Sideways',
#  'The Green Hornet',
#  'The Killer Inside Me',
#  'The Lion King',
#  'From Hell',
#  'Top Hat',
#  'Rotor DR1',
#  'Step Brothers',
#  'The Great Raid',
#  'Love in the Time of Cholera',
#  'Marie Antoinette',
#  'Last Holiday',
#  'Edtv',
#  'The Wicked Lady',
#  'Welcome to the Rileys',
#  'My Sisters Keeper',
#  'The Longest Yard',
#  'When Did You Last See Your Father?',
#  'Stargate: The Ark of Truth',
#  'Click',
#  'Woman Thou Art Loosed',
#  'Plush',
#  'Repo Men',
#  '3000 Miles to Graceland',
#  'Step Up 3D',
#  'Intolerance',
#  'Body of Lies',
#  'About Schmidt',
#  'Major League',
#  'Mulan',
#  'Charlie and the Chocolate Factory',
#  'Memento',
#  'The Quiet American',
#  'Kung Fu Panda 2',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'O Brother, Where Art Thou?',
#  'The Hurt Locker',
#  'Thirteen Days',
#  'Licence to Kill',
#  'The Perfect Man',
#  'Dreaming of Joseph Lees',
#  'Funny Games',
#  'Suicide Squad',
#  'Sense and Sensibility',
#  'Glitter',
#  'The Pianist',
#  'Soul Surfer',
#  'United 93',
#  'Independence Day: Resurgence',
#  'The Lawnmower Man',
#  'The Game of Their Lives',
#  'Friday the 13th Part III',
#  'The Day After Tomorrow',
#  'American Pie',
#  'Sex, Lies, and Videotape',
#  'Timecop',
#  'Body Double',
#  'Curious George',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Nowhere to Run',
#  'Someone Like You...',
#  'The Darkest Hour',
#  'Fight to the Finish',
#  'Made of Honor',
#  'Cop Out',
#  'Monster',
#  'Superbad',
#  'The Great Gatsby',
#  'Total Recall',
#  'Shutter Island',
#  'Poohs Heffalump Movie',
#  'Unleashed',
#  'Chloe',
#  'How to Deal',
#  'Legion',
#  'I, Frankenstein',
#  'Angel Eyes',
#  'The Kite Runner',
#  'The Forest',
#  'Monsters, Inc.',
#  'Nighthawks',
#  'Veronica Guerin',
#  'George of the Jungle',
#  'Hells Angels',
#  'Get Low',
#  'The First Wives Club',
#  'Elysium',
#  '28 Weeks Later',
#  'Pocketful of Miracles',
#  'Disaster Movie',
#  'Echo Dr.',
#  'Married Life',
#  'Panic Room',
#  'Poultrygeist: Night of the Chicken Dead',
#  'Star Trek VI: The Undiscovered Country',
#  'Dear John',
#  'Troop Beverly Hills',
#  'Warrior',
#  'Les Misérables',
#  'Footloose',
#  'Out of the Furnace',
#  'Da Sweet Blood of Jesus',
#  'Harsh Times',
#  'The 6th Day',
#  'Maniac',
#  'Annie',
#  'Street Kings',
#  'Hav Plenty',
#  'Eraserhead',
#  'Songcatcher',
#  'Ca$h',
#  'Spy Game',
#  'A Very Harold & Kumar Christmas',
#  'The Princess and the Frog',
#  'Big Mommas House',
#  'To Kill a Mockingbird',
#  'Sorcerer',
#  'Ordinary People',
#  'Prophecy',
#  'Stranded',
#  'License to Wed',
#  'San Andreas',
#  'Transformers: Revenge of the Fallen',
#  'Space Dogs',
#  'The Last Samurai',
#  'Black or White',
#  'Buffalo Soldiers',
#  'The Reader',
#  'The Fog',
#  'Americas Sweethearts',
#  'The Spiderwick Chronicles',
#  'The Stepfather',
#  'Interview with the Vampire',
#  'The To Do List',
#  'Dirty Grandpa',
#  'Cant Hardly Wait',
#  'Inside Man',
#  'Antarctic Edge: 70° South',
#  'Escape from Tomorrow',
#  'New York Stories',
#  'An Everlasting Piece',
#  'Left Behind',
#  'Scooby-Doo',
#  'Bad Words',
#  'The Sixth Sense',
#  'Brick Lane',
#  'After Earth',
#  'The Three Musketeers',
#  'Annie Get Your Gun',
#  'Dark Water',
#  'Dr. Dolittle 2',
#  'Hanging Up',
#  'Modern Times',
#  'Lucky Numbers',
#  'The Holiday',
#  'First Knight',
#  'Envy',
#  'The Adjustment Bureau',
#  'Gentlemans Agreement',
#  'Jersey Girl',
#  'Mission: Impossible II',
#  'Liar Liar',
#  'Another Year',
#  'Beverly Hills Cop II',
#  'Rockaway',
#  'Miss Congeniality',
#  'The Incredible Burt Wonderstone',
#  'Any Given Sunday',
#  'Topsy-Turvy',
#  'An Unfinished Life',
#  'Don Juan DeMarco',
#  'Need for Speed',
#  'Double Jeopardy',
#  'Tomorrowland',
#  'Young Adult',
#  'De-Lovely',
#  'Kids',
#  'Bobby',
#  'I Know What You Did Last Summer',
#  'Bully',
#  'The Scorpion King',
#  'Love Actually',
#  'Deep Rising',
#  'The Addams Family',
#  'Dead Man Down',
#  'Deceptive Practice: The Mysteries and Mentors of Ricky Jay',
#  'Dancer in the Dark',
#  'Horrible Bosses',
#  'The Campaign',
#  'The Witch',
#  'The Three Burials of Melquiades Estrada',
#  'Blue Jasmine',
#  'Antitrust',
#  'Song One',
#  'The Hours',
#  'Shrek',
#  'Skin Trade',
#  'A Perfect Getaway',
#  'Blonde Ambition',
#  'The Astronaut Farmer',
#  'Our Brand Is Crisis',
#  'Going the Distance',
#  'White Noise 2: The Light',
#  'Air Force One',
#  'Dogtown and Z-Boys',
#  'Nutty Professor II: The Klumps',
#  'My Big Fat Greek Wedding',
#  'Star Wars: Episode II - Attack of the Clones',
#  'The Blair Witch Project',
#  'The Flintstones in Viva Rock Vegas',
#  'Fireproof',
#  'The Rugrats Movie',
#  'The Savages',
#  '54',
#  'The Bourne Legacy',
#  'Face/Off',
#  'Tombstone',
#  'The Smurfs',
#  'Beverly Hills Cop III',
#  'Pitch Perfect 2',
#  'Whatever Works',
#  'Club Dread',
#  'Hobo with a Shotgun',
#  'Six-String Samurai',
#  'I, Robot',
#  'Death Becomes Her',
#  'Frat Party',
#  'Grindhouse',
#  'Swimfan',
#  'Clueless',
#  'Thr3e',
#  'Christmas with the Kranks',
#  'Salvador',
#  'Signs',
#  'The Hebrew Hammer',
#  'Aliens in the Attic',
#  'Firefox',
#  'Dead Like Me: Life After Death',
#  'I Got the Hook Up',
#  'Ever After: A Cinderella Story',
#  'Paranormal Activity 4',
#  'The Blue Bird',
#  'Escape from New York',
#  'The Veil',
#  'Gangster Squad',
#  'Coraline',
#  'You Dont Mess with the Zohan',
#  'Crank',
#  'The Duchess',
#  'Promised Land',
#  'The Trouble with Harry',
#  'The Social Network',
#  'Barnyard',
#  'Chasing Papi',
#  'Battle for the Planet of the Apes',
#  'Night at the Museum',
#  'Cop Land',
#  'Krush Groove',
#  'Love Happens',
#  'The Covenant',
#  'Mommie Dearest',
#  'Star Trek',
#  'Charlie Bartlett',
#  'The Blue Lagoon',
#  'Janky Promoters',
#  'Novocaine',
#  'Random Hearts',
#  'Richard III',
#  'X-Men: The Last Stand',
#  'Good Intentions',
#  'The Thief and the Cobbler',
#  'Saving Face',
#  'The Men Who Stare at Goats',
#  'Ishtar',
#  'Wag the Dog',
#  'Tank Girl',
#  'Flyboys',
#  'You Only Live Twice',
#  'Piranha 3D',
#  'The Smurfs 2',
#  'Kicks',
#  'August Rush',
#  'Tucker and Dale vs Evil',
#  'The Hangover Part II',
#  'A History of Violence',
#  'Darling Companion',
#  'Vanilla Sky',
#  'Caravans',
#  '10 Days in a Madhouse',
#  'Ice Age: Continental Drift',
#  'Logans Run',
#  'Duets',
#  'Seven Pounds',
#  'The Mask of Zorro',
#  'Scary Movie 3',
#  'Woman in Gold',
#  'Home Alone 2: Lost in New York',
#  'City Island',
#  'Sydney White',
#  'Thunder and the House of Magic',
#  'The Edge',
#  'White House Down',
#  'The Man Who Shot Liberty Valance',
#  'Earth to Echo',
#  'Wild Things',
#  'Hotel Transylvania',
#  'The 51st State',
#  'Bambi',
#  'Zoom',
#  'TRON: Legacy',
#  'South Park: Bigger, Longer & Uncut',
#  'The Big Year',
#  'An American Carol',
#  'Boyz n the Hood',
#  'Warlock',
#  'Survivor',
#  'Jackie Brown',
#  'Mr. Smith Goes to Washington',
#  'Twins',
#  'Tarnation',
#  'The Time Travelers Wife',
#  'Bulworth',
#  'Simon Birch',
#  'Home Run',
#  'Dream House',
#  'Charlottes Web',
#  'The Abyss',
#  'Garden State',
#  'Scream 3',
#  'Harry Potter and the Order of the Phoenix',
#  'Out of Time',
#  'The Fault in Our Stars',
#  '20,000 Leagues Under the Sea',
#  'Slow West',
#  'The Valley of Decision',
#  'The Players Club',
#  'Infamous',
#  'Marvins Room',
#  'Next Day Air',
#  'The Rage: Carrie 2',
#  'The In Crowd',
#  'North Country',
#  'The Tree of Life',
#  'Goldfinger',
#  'Big Trouble in Little China',
#  'Meeks Cutoff',
#  'Nebraska',
#  'Disturbia',
#  'Gods and Monsters',
#  'Down to You',
#  'Definitely, Maybe',
#  'My Dog Tulip',
#  'The Worlds Fastest Indian',
#  'The Night Visitor',
#  'Idle Hands',
#  'I Love You Phillip Morris',
#  'Lion of the Desert',
#  'No Reservations',
#  'Magic Mike',
#  'In Cold Blood',
#  'The Sound of Music',
#  'Wal-Mart: The High Cost of Low Price',
#  'The Secret Life of Walter Mitty',
#  'Half Baked',
#  'Million Dollar Arm',
#  '1941',
#  'Session 9',
#  'Meet Dave',
#  'The Benchwarmers',
#  'Maurice',
#  'The Wackness',
#  'Admission',
#  'Valentine',
#  'Circumstance',
#  'Witness',
#  'The Terminator',
#  'Digimon: The Movie',
#  '8MM',
#  'The Red Violin',
#  'Analyze This',
#  'The River Wild',
#  'Saw: The Final Chapter',
#  'The Five-Year Engagement',
#  'The Siege',
#  '42',
#  'Enough',
#  'Hes Just Not That Into You',
#  'Payback',
#  'Action Jackson',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'Close Range',
#  'Trance',
#  'The Misfits',
#  'The Glass House',
#  'DragonHeart',
#  '21 & Over',
#  'In the Heart of the Sea',
#  'No Mans Land: The Rise of Reeker',
#  'The Expendables 2',
#  'The Odd Life of Timothy Green',
#  'Whats Eating Gilbert Grape',
#  'Beastly',
#  'Delgo',
#  'Eragon',
#  'Killing Zoe',
#  'Good',
#  'Keanu',
#  'Shanghai Calling',
#  'Miss Potter',
#  'The Indian in the Cupboard',
#  'Star Trek Beyond',
#  'Love Letters',
#  'The Kingdom',
#  'Inside Llewyn Davis',
#  'Hoodwinked!',
#  'Rambo III',
#  'Slackers',
#  'The Legend of Hercules',
#  'Topaz',
#  'A Sound of Thunder',
#  'Highlander: The Final Dimension',
#  'The Big Bounce',
#  'Cypher',
#  'The Nutty Professor',
#  'I Am Sam',
#  'Cloudy with a Chance of Meatballs 2',
#  'Pay It Forward',
#  'The Bad News Bears',
#  'Under the Rainbow',
#  'Leaving Las Vegas',
#  'Hey Arnold! The Movie',
#  'Submarine',
#  'Burnt',
#  'Days of Heaven',
#  'Pieces of April',
#  'Ask Me Anything',
#  'The Rise of the Krays',
#  'L.I.E.',
#  'Red Tails',
#  'Lesbian Vampire Killers',
#  'The Informant!',
#  'Jason Goes to Hell: The Final Friday',
#  'Final Destination',
#  'The Last Exorcism Part II',
#  'Soul Men',
#  'Exorcist II: The Heretic',
#  'Hanna',
#  'Deadpool',
#  'Observe and Report',
#  'The Clan of the Cave Bear',
#  'Flawless',
#  'Blood Work',
#  'Youve Got Mail',
#  'The Spy Who Loved Me',
#  'American Splendor',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Chain Letter',
#  'The Tuxedo',
#  'Legends of the Fall',
#  'Get Carter',
#  'Tuck Everlasting',
#  'The Maids Room',
#  'From Justin to Kelly',
#  'Moms Night Out',
#  'A Guy Thing',
#  'Heartbeeps',
#  'Eulogy',
#  'Gentlemen Broncos',
#  'Give Me Shelter',
#  'Felicias Journey',
#  'Everything Must Go',
#  'The Last Waltz',
#  'The New Guy',
#  'Bulletproof Monk',
#  'Catch That Kid',
#  'Underworld: Rise of the Lycans',
#  'Insidious: Chapter 3',
#  'Slacker',
#  'Wrong Turn',
#  'I Spy',
#  'Not Easily Broken',
#  'Flash of Genius',
#  'Texas Chainsaw 3D',
#  'Still Alice',
#  'The Boss',
#  'All About Steve',
#  'Let Me In',
#  'Confidence',
#  'Half Past Dead',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Wall Street: Money Never Sleeps',
#  'The Conversation',
#  'Safe Haven',
#  'Serenity',
#  'Domino',
#  'The Other Guys',
#  'Dear Frankie',
#  'D-Tox',
#  'The Ring Two',
#  'Inside Out',
#  'Shadow of the Vampire',
#  'American Beast',
#  'Austin Powers in Goldmember',
#  'Jupiter Ascending',
#  'Barneys Great Adventure',
#  'War',
#  'The Amazing Spider-Man 2',
#  'Escape Plan',
#  'Keeping the Faith',
#  'The Express',
#  'Savage Grace',
#  'Little Black Book',
#  'The Help',
#  'Friends with Money',
#  'Yes Man',
#  'Trainspotting',
#  'Monster House',
#  'Addicted',
#  'Beautiful Creatures',
#  'Chicago',
#  'My Bloody Valentine',
#  'Hocus Pocus',
#  'Mr. Deeds',
#  'Grosse Pointe Blank',
#  'Lakeview Terrace',
#  'Psycho',
#  'Harry Potter and the Half-Blood Prince',
#  'Déjà Vu',
#  'Remember Me',
#  'The Sweeney',
#  'Never Say Never Again',
#  'Crocodile Dundee in Los Angeles',
#  'The Black Hole',
#  'The Thirteenth Floor',
#  'Jackass: The Movie',
#  'Reno 911!: Miami',
#  'Broken Arrow',
#  'Cabin Fever',
#  'The Equalizer',
#  'The Walking Deceased',
#  'Chasing Liberty',
#  'Feast',
#  'The Kings Speech',
#  'Jack Reacher',
#  'Where the Wild Things Are',
#  'Falcon Rising',
#  'Wish I Was Here',
#  'Where the Truth Lies',
#  'The Da Vinci Code',
#  'Pirates of the Caribbean: Dead Mans Chest',
#  'Quest for Fire',
#  'Legal Eagles',
#  'The Second Best Exotic Marigold Hotel',
#  'Triangle',
#  'Buffalo 66',
#  'Home for the Holidays',
#  'The Net',
#  'The Lovely Bones',
#  'Rosewater',
#  'Gandhi',
#  'Silent Running',
#  'Double Impact',
#  'The Man from Earth',
#  'Old Joy',
#  'Patch Adams',
#  'The Cavemans Valentine',
#  'Chicken Run',
#  '300: Rise of an Empire',
#  'Mary Poppins',
#  'Lilo & Stitch',
#  'The Ladykillers',
#  'Angelas Ashes',
#  'Dope',
#  'John Q',
#  'The Exorcist',
#  'Red Dawn',
#  'Jakob the Liar',
#  'The Godfather',
#  'Enders Game',
#  'The Italian Job',
#  'Disclosure',
#  'The Act of Killing',
#  'Spellbound',
#  'Days of Thunder',
#  'The Broadway Melody',
#  'Southpaw',
#  'Star Trek: The Motion Picture',
#  'Monsters Ball',
#  'The Passion of the Christ',
#  'Lost in Space',
#  'The Libertine',
#  'Abraham Lincoln: Vampire Hunter',
#  'The Core',
#  'The Egyptian',
#  'Around the World in 80 Days',
#  'Queen of the Damned',
#  'Teenage Mutant Ninja Turtles',
#  'Auto Focus',
#  '3 Ninjas Kick Back',
#  'Subconscious',
#  'Ella Enchanted',
#  'A Simple Wish',
#  'Chairman of the Board',
#  'Final Destination 5',
#  'Drillbit Taylor',
#  'Gods Not Dead 2',
#  'Edmond',
#  'Beverly Hills Cop',
#  'Deep Impact',
#  'After.Life',
#  'Dark City',
#  'Riding in Cars with Boys',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Mr. Beans Holiday',
#  'The Great Escape',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Small Soldiers',
#  'Mystic Pizza',
#  'The Other Woman',
#  'Bathing Beauty',
#  'LOL',
#  'Requiem for a Dream',
#  '2:13',
#  'Celebrity',
#  'Fever Pitch',
#  'Inside Deep Throat',
#  'Re-Kill',
#  'Gods and Generals',
#  'Pitch Perfect',
#  'Babe',
#  'Kung Fu Panda',
#  'Universal Soldier: The Return',
#  'Under the Skin',
#  'The Bridge of San Luis Rey',
#  'Lolita',
#  'Malevolence',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'Couples Retreat',
#  'The Interview',
#  'The Lion of Judah',
#  'Live Free or Die Hard',
#  'Sahara',
#  'The Crow',
#  'The Wolverine',
#  'Beloved',
#  'John Carter',
#  'Saw III',
#  'Mickey Blue Eyes',
#  'American Hero',
#  'Mindhunters',
#  'End of the Spear',
#  'A Good Day to Die Hard',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Shadow Conspiracy',
#  'Deterrence',
#  'Shes Gotta Have It',
#  'The Best Man',
#  '20 Dates',
#  'Spy Kids 3-D: Game Over',
#  'Fifty Dead Men Walking',
#  'Hellboy',
#  'National Lampoon’s Van Wilder',
#  'The Big Short',
#  'The Mechanic',
#  'War of the Worlds',
#  'Paranormal Activity: The Marked Ones',
#  'Trade Of Innocents',
#  'Barry Munday',
#  'Me Before You',
#  'Spanglish',
#  'The Master of Disguise',
#  'The Divide',
#  'WarGames',
#  'Born to Fly: Elizabeth Streb vs. Gravity',
#  'Show Boat',
#  'Iris',
#  'For Your Eyes Only',
#  'Howard the Duck',
#  'Stuart Little 2',
#  'This Means War',
#  'Hard Rain',
#  'The Nuns Story',
#  'Among Giants',
#  'Top Gun',
#  'New Nightmare',
#  'The Fast and the Furious',
#  'Outbreak',
#  'Shopgirl',
#  'Never Let Me Go',
#  'Dark Blue',
#  'Hitch',
#  'Secretary',
#  'The Awakening',
#  'Little Nicky',
#  'The Fan',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'A Madea Christmas',
#  'The Road to El Dorado',
#  'Hang em High',
#  'The Oh in Ohio',
#  'Mighty Joe Young',
#  'Creepshow',
#  'Die Hard 2',
#  'F.I.S.T.',
#  'The Pursuit of D.B. Cooper',
#  'In Bruges',
#  'Chappie',
#  'Things We Lost in the Fire',
#  'Wont Back Down',
#  'Message in a Bottle',
#  'Moon',
#  'Open Season',
#  'A Walk on the Moon',
#  'Bound',
#  'Apollo 18',
#  'Original Sin',
#  'The Tourist',
#  'The Apostle',
#  'The Art of Getting By',
#  'The Cold Light of Day',
#  'Theres Always Woodstock',
#  'Birth',
#  'Big Fish',
#  'Galaxina',
#  'The League of Extraordinary Gentlemen',
#  'Clash of the Titans',
#  'Frailty',
#  'Men in Black II',
#  'The Pacifier',
#  'The Verdict',
#  'Hollywood Homicide',
#  'Little Children',
#  'Shallow Hal',
#  'True Grit',
#  'Hit & Run',
#  'The Little Vampire',
#  'The Visual Bible: The Gospel of John',
#  'Rounders',
#  '1982',
#  'Austin Powers: International Man of Mystery',
#  'The Ant Bully',
#  'Untraceable',
#  '2012',
#  'R.L. Stines Monsterville: The Cabinet of Souls',
#  'Don McKay',
#  'Amistad',
#  'Maggie',
#  'Star Trek II: The Wrath of Khan',
#  'Just Like Heaven',
#  'Terminator 3: Rise of the Machines',
#  'My Best Friends Girl',
#  'Fight Valley',
#  ...]

# %% [markdown]
# Βοηθητικές συναρτήσεις για την εύρεση ίδιας δεκαετίας

# %%
#Για εύρεση χρονίας
prolog.assertz('''(firstKCharacters(_, 0, []))''')
prolog.assertz('''(firstKCharacters([X|L1], K, [X|L]):-
K > 0,
Km1 is K - 1,
firstKCharacters(L1, Km1, L))''')

# %%
#Μετατροπή ημερομηνίας σε integer
prolog.assertz('''(string_to_Int(Str,Num,X):-
 string_to_list(Str,L),
 firstKCharacters(L,Num,K),
 string_to_list(D,K),
 atom_number(D,X))''')

# %%
prolog.assertz('''(same_release_date(X,Y):-
release_date(X,K1),
release_date(Y,K2),
string_to_Int(K1,4,Int1),
string_to_Int(K2,4,Int2),
Res1 is Int1-Int2,
Res is abs(Res1),
Res =< 10,
X\=Y)''')

# %% [markdown]
# Προσθήκη κατηγορήματος για εύρεση κοινής δεκαετίας

# %%
def same_release_date(movie):
  q = prolog.query("same_release_date('" + movie + "', M)")
  ans = []
  for soln in q:
      ans.append(soln["M"])
  return list(set(ans))

# %%
same_release_date("Avatar")
# Out:
# ['Impostor',
#  'Fabled',
#  'The Blade of Don Juan',
#  'I Want Someone to Eat Cheese With',
#  'Casino Royale',
#  'Dolphin Tale 2',
#  'Automata',
#  'Exodus: Gods and Kings',
#  'Rocky Balboa',
#  'Hero',
#  'School of Rock',
#  'Beyond the Black Rainbow',
#  'The Jacket',
#  '10 Things I Hate About You',
#  'Dry Spell',
#  'Facing the Giants',
#  'The Manchurian Candidate',
#  'The Visit',
#  '51 Birch Street',
#  'Arbitrage',
#  'The Good Girl',
#  'Brooklyn Rules',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Bats',
#  'Aquamarine',
#  'My Name Is Bruce',
#  'See Spot Run',
#  'Taking Woodstock',
#  'The Jungle Book 2',
#  'My Life in Ruins',
#  'Monsters vs Aliens',
#  'Due Date',
#  'Damsels in Distress',
#  'Turbo',
#  'Ida',
#  'The Sisterhood of the Traveling Pants 2',
#  'Baby Geniuses',
#  'Aberdeen',
#  'How to Lose Friends & Alienate People',
#  'Happy Feet',
#  'Bolt',
#  'The Lake House',
#  'At First Sight',
#  'Yes',
#  'The Dead Undead',
#  'Martian Child',
#  'Mirrormask',
#  'Megamind',
#  'The Little Prince',
#  'Dolphins and Whales: Tribes of the Ocean',
#  'House at the End of the Drive',
#  'The Simpsons Movie',
#  'No Country for Old Men',
#  '16 Blocks',
#  'Identity',
#  'Butterfly on a Wheel',
#  'The Ninth Gate',
#  'Iraq for Sale: The War Profiteers',
#  'Tracker',
#  'Far from Heaven',
#  'Wicked Blood',
#  'The Adventures of Elmo in Grouchland',
#  'The Water Diviner',
#  'G.I. Joe: Retaliation',
#  'Open Water',
#  '13 Hours: The Secret Soldiers of Benghazi',
#  'Death at a Funeral',
#  'Fat Albert',
#  'Wuthering Heights',
#  'A Haunted House 2',
#  'Shrek Forever After',
#  'The Importance of Being Earnest',
#  'The Spectacular Now',
#  'Trouble with the Curve',
#  'Gone in Sixty Seconds',
#  'Jack Ryan: Shadow Recruit',
#  'Two Can Play That Game',
#  'Sharkskin',
#  'Pitch Black',
#  'Evil Dead',
#  'Fighting Tommy Riley',
#  'Legend of a Rabbit',
#  'The Hadza:  Last of the First',
#  'Office Space',
#  'Terminator Salvation',
#  'Hatchet',
#  'Road Hard',
#  'The Final Destination',
#  'Gangsters Paradise: Jerusalema',
#  'The Theory of Everything',
#  'Stoker',
#  'Out of Inferno',
#  'Autumn in New York',
#  'The Messenger',
#  'Ultraviolet',
#  'Transformers: Age of Extinction',
#  'The Best Exotic Marigold Hotel',
#  'The Yards',
#  'Annabelle',
#  'Bedazzled',
#  'Driven',
#  'The Hammer',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Red Planet',
#  'Rollerball',
#  'Ghost Rider',
#  'The Dangerous Lives of Altar Boys',
#  'Full Frontal',
#  'Im Not There.',
#  'Dogtooth',
#  'Dear Wendy',
#  'Bachelorette',
#  '90 Minutes in Heaven',
#  'Bamboozled',
#  'Public Enemies',
#  'Slacker Uprising',
#  'Race',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Born Of War',
#  'Changing Lanes',
#  '3:10 to Yuma',
#  'Being John Malkovich',
#  'Julie & Julia',
#  'The Night Listener',
#  'The Brothers',
#  'Paris, je taime',
#  'The Spy Next Door',
#  'Sex Tape',
#  'Paul',
#  'Johnson Family Vacation',
#  'Code of Honor',
#  'The Perfect Host',
#  'Kangaroo Jack',
#  'Short Cut to Nirvana: Kumbh Mela',
#  'Scoop',
#  'Unfinished Business',
#  'Herbie Fully Loaded',
#  'Bowfinger',
#  'Get Over It',
#  'The Sessions',
#  'Y Tu Mamá También',
#  'Regression',
#  'Instinct',
#  'Die Another Day',
#  'W.',
#  'Harold & Kumar Go to White Castle',
#  'The Lord of the Rings: The Return of the King',
#  'Shame',
#  'Catch a Fire',
#  'Elektra',
#  'Big Eyes',
#  'The Class',
#  'Groove',
#  'The Whole Ten Yards',
#  'The Baader Meinhof Complex',
#  'Wasabi',
#  'Harry Potter and the Goblet of Fire',
#  'Yesterday Was a Lie',
#  'How to Train Your Dragon',
#  'Ex Machina',
#  'Black Swan',
#  'Extremely Loud & Incredibly Close',
#  'Three to Tango',
#  'Black Snake Moan',
#  'Hands of Stone',
#  'Motherhood',
#  'Old Dogs',
#  'Shark Lake',
#  'Son of God',
#  'Mi America',
#  'The Naked Ape',
#  'Life as a House',
#  'Secretariat',
#  'Guardians of the Galaxy',
#  'Straightheads',
#  'Spectre',
#  'Tumbleweeds',
#  'Batman Begins',
#  'Stitches',
#  'Tower Heist',
#  'Troll Hunter',
#  'Lords of London',
#  'Shade',
#  'The Game Plan',
#  'Goodbye Bafana',
#  'The Damned United',
#  'Centurion',
#  'Queen Crab',
#  'Boat Trip',
#  'Oblivion',
#  'The Grudge',
#  'The Ridiculous 6',
#  'Skyline',
#  'The Other Boleyn Girl',
#  'The Horse Boy',
#  'Mad Max: Fury Road',
#  'The Haunted Mansion',
#  'Awake',
#  'The Huntsman: Winters War',
#  'Teeth and Blood',
#  'Ghosts of Mars',
#  'Precious',
#  'Spirited Away',
#  'Arlington Road',
#  'The Story of Us',
#  'The Mudge Boy',
#  'Deliver Us from Evil',
#  'Godsend',
#  'Water for Elephants',
#  'The Life Before Her Eyes',
#  '21 Jump Street',
#  'Roll Bounce',
#  'Housefull',
#  'The Purge: Anarchy',
#  '8 Mile',
#  'Mean Girls',
#  'The Internship',
#  'V for Vendetta',
#  'One to Another',
#  'Prom',
#  'Bullet to the Head',
#  'The Skeleton Key',
#  'The Young Unknowns',
#  'Fantastic Four',
#  'Lincoln',
#  'Slow Burn',
#  'Brighton Rock',
#  'The Christmas Candle',
#  'My Soul to Take',
#  'Scott Pilgrim vs. the World',
#  'Deuce Bigalow: European Gigolo',
#  'Jack the Giant Slayer',
#  'Australia',
#  'Scary Movie 5',
#  'Fuel',
#  'Chicken Little',
#  'The Green Hornet',
#  'Moliere',
#  'Sideways',
#  'The Killer Inside Me',
#  'From Hell',
#  'Rotor DR1',
#  'Step Brothers',
#  'The Great Raid',
#  'Love in the Time of Cholera',
#  'Marie Antoinette',
#  'Antiviral',
#  'Last Holiday',
#  'Edtv',
#  'Welcome to the Rileys',
#  'My Sisters Keeper',
#  'Ong Bak 2',
#  'The Longest Yard',
#  'When Did You Last See Your Father?',
#  'Stargate: The Ark of Truth',
#  'Click',
#  'Woman Thou Art Loosed',
#  'Plush',
#  'Repo Men',
#  '3000 Miles to Graceland',
#  'Hum To Mohabbat Karega',
#  'Step Up 3D',
#  'About Schmidt',
#  'Body of Lies',
#  'Charlie and the Chocolate Factory',
#  'Memento',
#  'The Quiet American',
#  'Kung Fu Panda 2',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'O Brother, Where Art Thou?',
#  'Alatriste',
#  'The Hurt Locker',
#  'Thirteen Days',
#  'The Perfect Man',
#  'Dreaming of Joseph Lees',
#  'Carnage',
#  'Funny Games',
#  'Suicide Squad',
#  'Glitter',
#  'The Pianist',
#  'Soul Surfer',
#  'United 93',
#  'Independence Day: Resurgence',
#  'The Game of Their Lives',
#  'The Day After Tomorrow',
#  'Nine Queens',
#  'American Pie',
#  'Evil Words',
#  'Space Battleship Yamato',
#  'Someone Like You...',
#  'Curious George',
#  'Night at the Museum: Battle of the Smithsonian',
#  'The Darkest Hour',
#  'Fight to the Finish',
#  'Made of Honor',
#  'Cop Out',
#  'Monster',
#  'Superbad',
#  'The Great Gatsby',
#  'Shutter Island',
#  'Poohs Heffalump Movie',
#  'Unleashed',
#  'Chloe',
#  'How to Deal',
#  'Legion',
#  'I, Frankenstein',
#  'The Other Dream Team',
#  'Angel Eyes',
#  'The Kite Runner',
#  'The Forest',
#  'Monsters, Inc.',
#  'Veronica Guerin',
#  'As It Is in Heaven',
#  'Get Low',
#  'Elysium',
#  '28 Weeks Later',
#  'Poultrygeist: Night of the Chicken Dead',
#  'Disaster Movie',
#  'Echo Dr.',
#  'Married Life',
#  'Panic Room',
#  'Flame & Citron',
#  'Dear John',
#  'Warrior',
#  'Firestorm',
#  'Les Misérables',
#  'Out of the Furnace',
#  'Da Sweet Blood of Jesus',
#  'Harsh Times',
#  'Rampage',
#  'The Blood of My Brother: A Story of Death in Iraq',
#  'The 6th Day',
#  'Maniac',
#  'Annie',
#  'Street Kings',
#  'Songcatcher',
#  'Ca$h',
#  'Spy Game',
#  'A Very Harold & Kumar Christmas',
#  'The Princess and the Frog',
#  'Big Mommas House',
#  'Kites',
#  'Stranded',
#  'License to Wed',
#  'San Andreas',
#  'Transformers: Revenge of the Fallen',
#  'Space Dogs',
#  'The Last Samurai',
#  'Black or White',
#  'Buffalo Soldiers',
#  'The Reader',
#  'The Spiderwick Chronicles',
#  'Americas Sweethearts',
#  'The Stepfather',
#  'The To Do List',
#  'Dirty Grandpa',
#  'Inside Man',
#  'Abandoned',
#  'Escape from Tomorrow',
#  'Antarctic Edge: 70° South',
#  'An Everlasting Piece',
#  'Chocolate: Deep Dark Secrets',
#  'Left Behind',
#  'Bad Words',
#  'In the Name of the King III',
#  'After Earth',
#  'Brick Lane',
#  'Dr. Dolittle 2',
#  'Dark Water',
#  'Hanging Up',
#  'Duma',
#  'The Three Musketeers',
#  'Lucky Numbers',
#  'The Holiday',
#  'Soul Kitchen',
#  'Envy',
#  'The Adjustment Bureau',
#  'Jersey Girl',
#  'Mission: Impossible II',
#  'The Assassin',
#  'Another Year',
#  'Silmido',
#  'Rockaway',
#  'Miss Congeniality',
#  'The Puffy Chair',
#  'For Greater Glory - The True Story of Cristiada',
#  'The Incredible Burt Wonderstone',
#  'Any Given Sunday',
#  'An Unfinished Life',
#  'Topsy-Turvy',
#  'Stolen Summer',
#  'Waltz with Bashir',
#  'Need for Speed',
#  'Double Jeopardy',
#  'Tomorrowland',
#  'Young Adult',
#  'De-Lovely',
#  'Bobby',
#  'Bully',
#  'The Scorpion King',
#  'Love Actually',
#  'Sparkler',
#  'Dead Man Down',
#  'Deceptive Practice: The Mysteries and Mentors of Ricky Jay',
#  'Dancer in the Dark',
#  'Horrible Bosses',
#  'The Campaign',
#  'The Witch',
#  'The Three Burials of Melquiades Estrada',
#  'Blue Jasmine',
#  'Antitrust',
#  'Song One',
#  'The Hours',
#  'Shrek',
#  'Skin Trade',
#  'A Perfect Getaway',
#  'Blonde Ambition',
#  'Redemption Road',
#  'Our Brand Is Crisis',
#  'The Astronaut Farmer',
#  'Going the Distance',
#  'White Noise 2: The Light',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Dogtown and Z-Boys',
#  'Nutty Professor II: The Klumps',
#  'My Big Fat Greek Wedding',
#  'The Blair Witch Project',
#  'The Flintstones in Viva Rock Vegas',
#  'Fireproof',
#  'The Savages',
#  'The Bourne Legacy',
#  'The Smurfs',
#  'Pitch Perfect 2',
#  'Whatever Works',
#  'Club Dread',
#  'Hobo with a Shotgun',
#  'I, Robot',
#  'Frat Party',
#  'Grindhouse',
#  'Instructions Not Included',
#  'Swimfan',
#  'Thr3e',
#  'Mama',
#  'Christmas with the Kranks',
#  'Signs',
#  'The Hebrew Hammer',
#  'Aliens in the Attic',
#  'Paranormal Activity 4',
#  'Dead Like Me: Life After Death',
#  'The Veil',
#  'Gangster Squad',
#  'Coraline',
#  'You Dont Mess with the Zohan',
#  'Mondays in the Sun',
#  'The Best Offer',
#  'Crank',
#  'Promised Land',
#  'The Duchess',
#  'The Social Network',
#  'Barnyard',
#  'Chasing Papi',
#  'Night at the Museum',
#  'Diamond Ruff',
#  'Love Happens',
#  'Rang De Basanti',
#  'The Covenant',
#  'Housebound',
#  'The Harvest (La Cosecha)',
#  'Star Trek',
#  'Charlie Bartlett',
#  'Janky Promoters',
#  'Novocaine',
#  'Random Hearts',
#  'X-Men: The Last Stand',
#  'Good Intentions',
#  'Growing Up Smith',
#  'Saving Face',
#  'The Men Who Stare at Goats',
#  'Boynton Beach Club',
#  'Flyboys',
#  'Piranha 3D',
#  'The Smurfs 2',
#  'Kicks',
#  'August Rush',
#  'Tucker and Dale vs Evil',
#  'The Hangover Part II',
#  'A History of Violence',
#  'Darling Companion',
#  'The Case of the Grinning Cat',
#  'Ice Age: Continental Drift',
#  '10 Days in a Madhouse',
#  'Vanilla Sky',
#  'Seven Pounds',
#  'Duets',
#  'Thunder and the House of Magic',
#  'Scary Movie 3',
#  'Woman in Gold',
#  'City Island',
#  'Sydney White',
#  'White House Down',
#  'Earth to Echo',
#  'Hotel Transylvania',
#  'The 51st State',
#  'Zoom',
#  'TRON: Legacy',
#  'South Park: Bigger, Longer & Uncut',
#  'The Big Year',
#  'An American Carol',
#  'Survivor',
#  'Tarnation',
#  'The Time Travelers Wife',
#  'Home Run',
#  'Dream House',
#  'Charlottes Web',
#  'Garden State',
#  'Scream 3',
#  'Forbidden Kingdom',
#  'Harry Potter and the Order of the Phoenix',
#  'Out of Time',
#  'The Fault in Our Stars',
#  'Slow West',
#  'Infamous',
#  'Next Day Air',
#  'The Rage: Carrie 2',
#  'The Tree of Life',
#  'The In Crowd',
#  'North Country',
#  'Meeks Cutoff',
#  'Nebraska',
#  'Disturbia',
#  'The Worlds Fastest Indian',
#  'Down to You',
#  'Definitely, Maybe',
#  'My Dog Tulip',
#  'Idle Hands',
#  'I Love You Phillip Morris',
#  'No Reservations',
#  'Magic Mike',
#  'Wal-Mart: The High Cost of Low Price',
#  'Gunless',
#  'The Secret Life of Walter Mitty',
#  'Million Dollar Arm',
#  'Session 9',
#  'Beneath Hill 60',
#  'Meet Dave',
#  'The Benchwarmers',
#  'The Wackness',
#  'Admission',
#  'Valentine',
#  'A Very Long Engagement',
#  'Circumstance',
#  'Digimon: The Movie',
#  '8MM',
#  'Lonesome Jim',
#  'Mongol: The Rise of Genghis Khan',
#  'Analyze This',
#  'Saw: The Final Chapter',
#  'The Five-Year Engagement',
#  '42',
#  'Enough',
#  'Hes Just Not That Into You',
#  'Payback',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'Close Range',
#  'Trance',
#  'The Glass House',
#  'Never Again',
#  'In the Heart of the Sea',
#  '21 & Over',
#  'No Mans Land: The Rise of Reeker',
#  'The Expendables 2',
#  'Rocket Singh: Salesman of the Year',
#  'Screwed',
#  'The Odd Life of Timothy Green',
#  'Beastly',
#  'Delgo',
#  'Eragon',
#  'Good',
#  'Keanu',
#  'Shanghai Calling',
#  'Miss Potter',
#  'Star Trek Beyond',
#  'The Holy Girl',
#  'The Kingdom',
#  'Inside Llewyn Davis',
#  'Hoodwinked!',
#  'Slackers',
#  'The Legend of Hercules',
#  'A Sound of Thunder',
#  'The Big Bounce',
#  'Cypher',
#  'I Am Sam',
#  'Cloudy with a Chance of Meatballs 2',
#  'Pay It Forward',
#  'Hey Arnold! The Movie',
#  'I Want Your Money',
#  'Burnt',
#  'Pieces of April',
#  'Submarine',
#  'Censored Voices',
#  'Ask Me Anything',
#  'L.I.E.',
#  'Red Tails',
#  'The Informant!',
#  'Lesbian Vampire Killers',
#  'The Last Exorcism Part II',
#  'The Rise of the Krays',
#  'Final Destination',
#  'Remember Me, My Love',
#  'The World Is Not Enough',
#  'Soul Men',
#  'Hanna',
#  'Deadpool',
#  'Observe and Report',
#  'Flawless',
#  'Blood Work',
#  'American Splendor',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Chain Letter',
#  'The Tuxedo',
#  'Tuck Everlasting',
#  'Get Carter',
#  'The Maids Room',
#  'From Justin to Kelly',
#  'Moms Night Out',
#  'Sardaarji',
#  'A Guy Thing',
#  'Eulogy',
#  'Gentlemen Broncos',
#  'Give Me Shelter',
#  'Everything Must Go',
#  'American Heist',
#  'Felicias Journey',
#  'The New Guy',
#  'Bulletproof Monk',
#  'Catch That Kid',
#  'Underworld: Rise of the Lycans',
#  'Insidious: Chapter 3',
#  'Wrong Turn',
#  'I Spy',
#  'Not Easily Broken',
#  'Flash of Genius',
#  'Texas Chainsaw 3D',
#  'Still Alice',
#  'The Boss',
#  'All About Steve',
#  'Let Me In',
#  'Confidence',
#  'Half Past Dead',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'Wall Street: Money Never Sleeps',
#  'Pokémon: Spell of the Unknown',
#  'Safe Haven',
#  'Serenity',
#  'Domino',
#  'The Other Guys',
#  '8: The Mormon Proposition',
#  'D-Tox',
#  'Dear Frankie',
#  'District B13',
#  'The Ring Two',
#  'Inside Out',
#  'Shadow of the Vampire',
#  'American Beast',
#  'Maos Last Dancer',
#  'Austin Powers in Goldmember',
#  'Jupiter Ascending',
#  'The Children of Huang Shi',
#  'War',
#  'The Amazing Spider-Man 2',
#  'Mutant World',
#  'Escape Plan',
#  'Keeping the Faith',
#  'The Express',
#  'Tin Can Man',
#  'Savage Grace',
#  'Little Black Book',
#  'The Help',
#  'Friends with Money',
#  'Yes Man',
#  'Monster House',
#  'Addicted',
#  'Beautiful Creatures',
#  'Chicago',
#  'My Bloody Valentine',
#  'Mr. Deeds',
#  'Lakeview Terrace',
#  'Harry Potter and the Half-Blood Prince',
#  'Water & Power',
#  'Remember Me',
#  'The Sweeney',
#  'Crocodile Dundee in Los Angeles',
#  'The Thirteenth Floor',
#  'Why Did I Get Married Too?',
#  'Jackass: The Movie',
#  'Reno 911!: Miami',
#  'Cabin Fever',
#  'The Equalizer',
#  'The Walking Deceased',
#  'Chasing Liberty',
#  'Feast',
#  'Jack Reacher',
#  'The Kings Speech',
#  'Where the Wild Things Are',
#  'Falcon Rising',
#  'Wish I Was Here',
#  'Where the Truth Lies',
#  'Pirates of the Caribbean: Dead Mans Chest',
#  'The Da Vinci Code',
#  'The Second Best Exotic Marigold Hotel',
#  'Triangle',
#  'The Lovely Bones',
#  'Rosewater',
#  'The Man from Earth',
#  'Old Joy',
#  'The Cavemans Valentine',
#  'Asterix at the Olympic Games',
#  'Chicken Run',
#  '300: Rise of an Empire',
#  'Lilo & Stitch',
#  'The Ladykillers',
#  'Scooby-Doo',
#  'Angelas Ashes',
#  'Coming Home',
#  'Dope',
#  'John Q',
#  'Jakob the Liar',
#  'Enders Game',
#  'Guten Tag, Ramón',
#  'The Italian Job',
#  'Agora',
#  'The Act of Killing',
#  'Southpaw',
#  'A Beginners Guide to Snuff',
#  'Monsters Ball',
#  'The Passion of the Christ',
#  'The Libertine',
#  'Abraham Lincoln: Vampire Hunter',
#  'The Core',
#  'Around the World in 80 Days',
#  'Queen of the Damned',
#  'Teenage Mutant Ninja Turtles',
#  'Auto Focus',
#  'Subconscious',
#  'Ella Enchanted',
#  'Final Destination 5',
#  'The True Story of Puss n Boots',
#  'Drillbit Taylor',
#  'Gods Not Dead 2',
#  'Edmond',
#  'After.Life',
#  'Warm Bodies',
#  'Riding in Cars with Boys',
#  'Mr. Beans Holiday',
#  'War, Inc.',
#  'The Other Woman',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'LOL',
#  'Requiem for a Dream',
#  '2:13',
#  'Fever Pitch',
#  'Inside Deep Throat',
#  'Amen.',
#  'Re-Kill',
#  'Sarahs Key',
#  'Gods and Generals',
#  'Kung Fu Panda',
#  'Light from the Darkroom',
#  'Universal Soldier: The Return',
#  'Under the Skin',
#  'The Bridge of San Luis Rey',
#  'Malevolence',
#  'The Interview',
#  'Couples Retreat',
#  'The Lion of Judah',
#  'Live Free or Die Hard',
#  'Sahara',
#  'John Carter',
#  'The Wolverine',
#  'Saw III',
#  'American Hero',
#  'Mickey Blue Eyes',
#  'Mindhunters',
#  'End of the Spear',
#  'A Good Day to Die Hard',
#  'The Good, The Bad, The Weird',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Deterrence',
#  'The Best Man',
#  'Drive Hard',
#  'Fifty Dead Men Walking',
#  'Hellboy',
#  'Spy Kids 3-D: Game Over',
#  'National Lampoon’s Van Wilder',
#  'The Big Short',
#  'Downfall',
#  'Limbo',
#  'The Mechanic',
#  'War of the Worlds',
#  'Paranormal Activity: The Marked Ones',
#  'Trade Of Innocents',
#  'Barry Munday',
#  'Me Before You',
#  'Spanglish',
#  'Anatomy',
#  'The Master of Disguise',
#  'The Divide',
#  'Mutual Friends',
#  'Diary of a Mad Black Woman',
#  'Born to Fly: Elizabeth Streb vs. Gravity',
#  'Iris',
#  'This Means War',
#  'Stuart Little 2',
#  'Far from Men',
#  '8 Women',
#  'The Warriors Way',
#  'The Fast and the Furious',
#  'Shopgirl',
#  'Never Let Me Go',
#  'Dark Blue',
#  'Hitch',
#  'Secretary',
#  'The Awakening',
#  'Little Nicky',
#  'Talladega Nights: The Ballad of Ricky Bobby',
#  'A Madea Christmas',
#  'The Road to El Dorado',
#  'The Oh in Ohio',
#  'Chappie',
#  'In Bruges',
#  'Things We Lost in the Fire',
#  'Wont Back Down',
#  'Message in a Bottle',
#  'Moon',
#  'Open Season',
#  'A Walk on the Moon',
#  'Apollo 18',
#  'Original Sin',
#  'The Tourist',
#  'The Cold Light of Day',
#  'The Art of Getting By',
#  'Theres Always Woodstock',
#  'Birth',
#  'Big Fish',
#  'Men in Black II',
#  'Clash of the Titans',
#  'Frailty',
#  'The League of Extraordinary Gentlemen',
#  'Snow Flower and the Secret Fan',
#  'The Pacifier',
#  'Hollywood Homicide',
#  'Little Children',
#  'Once',
#  'Shallow Hal',
#  'True Grit',
#  'Hit & Run',
#  'The Little Vampire',
#  'The Visual Bible: The Gospel of John',
#  '1982',
#  'The Grandmaster',
#  'The Ant Bully',
#  'Untraceable',
#  '2012',
#  'I Love Your Work',
#  'R.L. Stines Monsterville: The Cabinet of Souls',
#  'Don McKay',
#  'Micmacs',
#  'Maggie',
#  'Just Like Heaven',
#  'My Best Friends Girl',
#  'Terminator 3: Rise of the Machines',
#  'Independence Daysaster',
#  'Fight Valley',
#  'Dave Chappelles Block Party',
#  'Bringing Out the Dead',
#  'Firewall',
#  'Betty Fisher and Other Stories',
#  'Childless',
#  'Friends with Benefits',
#  'Gandhi, My Father',
#  'Super',
#  'The Longshots',
#  'Christmas Mail',
#  'Rize',
#  'All Hat',
#  'Beauty Shop',
#  'The Devil Inside',
#  'The Original Kings of Comedy',
#  'The Work and the Glory',
#  'Runaway Bride',
#  'Loving Annabelle',
#  'Primer',
#  'Beerfest',
#  'Albert Nobbs',
#  'Detroit Rock City',
#  'All Is Lost',
#  'Phat Girlz',
#  'Space Chimps',
#  'Kinsey',
#  'A Better Life',
#  'Snow Day',
#  'The Last Legion',
#  'Fahrenheit 9/11',
#  'Scary Movie 2',
#  'Ramanujan',
#  'Peeples',
#  'The Messenger: The Story of Joan of Arc',
#  'Free State of Jones',
#  'The Taking of Pelham 1 2 3',
#  'Agent Cody Banks',
#  'Mirrors',
#  'The Boxtrolls',
#  'The Princess Diaries',
#  'This Thing of Ours',
#  'Wrath of the Titans',
#  'Dirty Pretty Things',
#  'Margaret',
#  'Kick-Ass 2',
#  'The Art of War',
#  'Foolish',
#  'Taxi to the Dark Side',
#  'Hearts in Atlantis',
#  'They',
#  'Because I Said So',
#  'Hope Springs',
#  'Ice Age: Dawn of the Dinosaurs',
#  'The Legend of Bagger Vance',
#  'Dumb and Dumber To',
#  'EuroTrip',
#  'Moonrise Kingdom',
#  'Elizabeth: The Golden Age',
#  'Jason Bourne',
#  'Letters to God',
#  'Funny Ha Ha',
#  'Our Kind of Traitor',
#  'Alpha and Omega',
#  'The Purge: Election Year',
#  'Taken',
#  'Frankenweenie',
#  'Nanny McPhee',
#  'Sympathy for Lady Vengeance',
#  'Bran Nue Dae',
#  'Sex With Strangers',
#  'Amnesiac',
#  'Unsullied',
#  'Hardball',
#  'Brothers',
#  'The Chorus',
#  'The Ugly Truth',
#  'Assault on Precinct 13',
#  'Paranormal Activity 3',
#  'The Hunger Games: Mockingjay - Part 2',
#  'How to Be Single',
#  'Out of the Dark',
#  'Bridget Jones: The Edge of Reason',
#  'The Book Thief',
#  'Victor Frankenstein',
#  'All the Kings Men',
#  'We Are Marshall',
#  'No End in Sight',
#  'Fast Five',
#  'Drinking Buddies',
#  'Wendy and Lucy',
#  'Journey 2: The Mysterious Island',
#  'Anywhere But Here',
#  'Winnie the Pooh',
#  'Attack the Block',
#  'Navy Seals vs. Zombies',
#  'New York Minute',
#  'The Little Ponderosa Zoo',
#  'The Impossible',
#  'Middle of Nowhere',
#  'Bad Teacher',
#  'A Room for Romeo Brass',
#  'The Brothers Grimm',
#  'Transcendence',
#  'Bloody Sunday',
#  'Alvin and the Chipmunks: The Road Chip',
#  'The Raven',
#  'Deep Blue Sea',
#  'Eastern Promises',
#  'Love & Other Drugs',
#  'Underworld: Evolution',
#  'Lord of War',
#  'Town & Country',
#  'Thor',
#  'Battleship',
#  'Hancock',
#  'Jab Tak Hai Jaan',
#  'A Christmas Carol',
#  'Control',
#  'Antwone Fisher',
#  'Jindabyne',
#  'To Save A Life',
#  'Legend of the Guardians: The Owls of GaHoole',
#  'Rust',
#  'The Mummy Returns',
#  'Without Men',
#  'Better Luck Tomorrow',
#  'School for Scoundrels',
#  ...]

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
prolog.retractall("find_similar_movies_5(X,Y)") #πετάμε τα κατηγορήματα, βοήθησε στην γρήγορη επεξεργασία τους χωρίς να τρέχουμε τα πάντα ξανά.
prolog.retractall("find_similar_movies_4(X,Y)")
prolog.retractall("find_similar_movies_3(X,Y)")
prolog.retractall("find_similar_movies_2(X,Y)")
prolog.retractall("find_similar_movies_1(X,Y)")

# %%
prolog.assertz('(find_similar_movies_5(X, Y) :- commonplot_high(X, Y),  commongenre_very(X, Y) )')
prolog.assertz('(find_similar_movies_4(X, Y) :- commonplot_high(X, Y),  commongenre_medium(X, Y), not(find_similar_movies_5(X, Y) ))')
prolog.assertz('(find_similar_movies_3(X, Y) :- commonplot_low(X, Y), commongenre_medium(X, Y), not(find_similar_movies_4(X, Y)), not(find_similar_movies_5(X, Y)) )')
prolog.assertz('(find_similar_movies_2(X, Y) :- commongenre_low(X, Y), commonplot_low(X, Y), not(find_similar_movies_3(X, Y)), not(find_similar_movies_4(X, Y)), not(find_similar_movies_5(X, Y)) )')
prolog.assertz('(find_similar_movies_1(X, Y) :- same_language(X, Y), common_col(X, Y), commonplot_low(X, Y), not(find_similar_movies_2(X, Y)), not(find_similar_movies_3(X, Y)), not(find_similar_movies_4(X, Y)), not(find_similar_movies_5(X, Y))  )')

# %%
q = prolog.query("find_similar_movies_5('Avatar', Y)")
s = set()
for soln in q:
  m = soln['Y'] 
  if m not in s:
    s.add(soln['Y'])
print(s)
# Out:
# {'Jimmy Neutron: Boy Genius', 'The Fifth Element', 'Jupiter Ascending'}

# %%
def simple_recommender(movie):
    print("new search")
    q = prolog.query("find_similar_movies_5('" + movie +"',M)")
    ans5 = []
    for soln in q:
        ans5.append(soln["M"])

    print(" 5 done")
    q = prolog.query("find_similar_movies_4('" + movie +"',M)")
    ans4 = []
    for soln in q:
        ans4.append(soln["M"])

    print(" 4 done")
    q = prolog.query("find_similar_movies_3('" + movie +"',M)")
    ans3 = []
    for soln in q:
        ans3.append(soln["M"])

    print(" 3 done")
    q = prolog.query("find_similar_movies_2('" + movie +"',M)")
    ans2 = []
    for soln in q:
        ans2.append(soln["M"])
    print(" 2 done")
    q = prolog.query("find_similar_movies_1('" + movie +"',M)")
    ans1 = []
    for soln in q:
        ans1.append(soln["M"])        

    #κάνουμε κάποιο Processing στα παραπάνω αποτελέσματα και επιστρέφουμε τις "όμοιες" ταινίες με φθίνουσα σειρά
    return list(set(ans5)), list(set(ans4)), list(set(ans3)), list(set(ans2)), list(set(ans1))

# %%
list(simple_recommender('Avatar'))[:5]
# Out:
# new search
#  5
#  4
#  3
#  2
# [['Jimmy Neutron: Boy Genius', 'The Fifth Element', 'Jupiter Ascending'],
#  ['Terminator Genisys',
#   'Planet of the Apes',
#   'Stargate: The Ark of Truth',
#   'Alien',
#   'You Only Live Twice',
#   'Home',
#   'Renaissance',
#   'I, Robot',
#   'Green Lantern',
#   'Battle: Los Angeles',
#   'Silent Running',
#   'Edge of Tomorrow',
#   'Meet Dave',
#   'Predator',
#   'A Monster in Paris',
#   'Star Trek Into Darkness',
#   'Lockout',
#   'Independence Day',
#   'Captain America: The Winter Soldier',
#   'Interstellar',
#   'Predators',
#   'Enders Game',
#   'Alien³',
#   'The Hitchhikers Guide to the Galaxy',
#   'Titan A.E.',
#   'John Carter',
#   'Aliens',
#   'Pirates of the Caribbean: On Stranger Tides',
#   'Treasure Planet',
#   'Planet 51'],
#  ['The Thief and the Cobbler',
#   '2001: A Space Odyssey',
#   'Falcon Rising',
#   'Impostor',
#   'RoboCop',
#   'Pixels',
#   'Mortal Kombat: Annihilation',
#   'Exodus: Gods and Kings',
#   'Three Kings',
#   'Captain America: Civil War',
#   'Percy Jackson: Sea of Monsters',
#   'The Adventures of Pluto Nash',
#   'Thunder and the House of Magic',
#   'Aliens vs Predator: Requiem',
#   'The 5th Wave',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'The Ice Pirates',
#   'Earth to Echo',
#   'Monsters vs Aliens',
#   'Solaris',
#   'Men in Black',
#   'Moonraker',
#   'Forbidden Kingdom',
#   'Iron Man 3',
#   'Thor: The Dark World',
#   'Abraham Lincoln: Vampire Hunter',
#   'The Little Prince',
#   'Split Second',
#   'How to Train Your Dragon 2',
#   'The Hunger Games: Mockingjay - Part 2',
#   'Resident Evil: Afterlife',
#   'The Matrix Reloaded',
#   'Valley of the Wolves: Iraq',
#   'Total Recall',
#   'Avengers: Age of Ultron',
#   'Dredd',
#   'The Matrix Revolutions',
#   'Zathura: A Space Adventure',
#   'G.I. Joe: Retaliation',
#   'Transformers: Dark of the Moon',
#   'Prometheus',
#   'Journey 2: The Mysterious Island',
#   'Shrek Forever After',
#   'Attack the Block',
#   'Species',
#   'The Expendables 3',
#   'Looper',
#   'Thor',
#   'Transformers: Age of Extinction',
#   'Riddick',
#   'AVP: Alien vs. Predator',
#   'Brave',
#   'Red Planet',
#   'Tora! Tora! Tora!',
#   'Doomsday',
#   'Lifeforce',
#   'The Wraith',
#   'Bill & Teds Bogus Journey',
#   'Star Trek',
#   'Beowulf',
#   'Armageddon',
#   'Alice in Wonderland',
#   'Captain America: The First Avenger',
#   '47 Ronin',
#   'Big Hero 6',
#   'The Three Musketeers',
#   'A Sound of Thunder',
#   'The Martian',
#   'Dune',
#   'A.I. Artificial Intelligence',
#   'Damnation Alley',
#   'Steel',
#   'Alien: Resurrection',
#   'Soldier',
#   'Apocalypto',
#   'Savva. Heart of the Warrior',
#   'How to Train Your Dragon',
#   'Escape from Planet Earth',
#   'Megaforce',
#   'Saints and Soldiers',
#   'Transformers',
#   'Children of Men',
#   'Maleficent',
#   'Journey to the Center of the Earth',
#   'Pompeii',
#   'Guardians of the Galaxy',
#   'Hercules',
#   'I Am Number Four',
#   'Men in Black II',
#   'Clash of the Titans',
#   'The Astronaut Farmer',
#   'Oblivion',
#   'Rambo: First Blood Part II',
#   'Mad Max: Fury Road',
#   'Starship Troopers',
#   'Cloverfield',
#   'Lions for Lambs',
#   'Hansel & Gretel: Witch Hunters',
#   'Minority Report',
#   'Force 10 from Navarone',
#   'Aliens in the Attic',
#   'Space Cowboys',
#   'Independence Daysaster',
#   'Fortress',
#   'Ant-Man',
#   'In Time',
#   'Babylon A.D.',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   'Insurgent',
#   'Men in Black 3',
#   'Dawn of the Planet of the Apes',
#   'Pacific Rim',
#   'The Hunger Games: Catching Fire',
#   'Oz: The Great and Powerful',
#   'The Hobbit: The Battle of the Five Armies',
#   'The Time Machine',
#   'Lucy',
#   'Dracula Untold',
#   'Idiocracy',
#   'Jurassic World',
#   'The Empire Strikes Back'],
#  ['The Thing',
#   'Barbarella',
#   'Ice Age: Dawn of the Dinosaurs',
#   'Automata',
#   'The Jacket',
#   'The Day the Earth Stood Still',
#   'Khumba',
#   'Elf',
#   'The Box',
#   '300: Rise of an Empire',
#   'The Wild Bunch',
#   'Sphere',
#   'Event Horizon',
#   'Code 46',
#   'Goosebumps',
#   'Agora',
#   'G.I. Jane',
#   'Alice Through the Looking Glass',
#   'A Scanner Darkly',
#   'The Invasion',
#   'Dark City',
#   'Spaceballs',
#   'Seven Samurai',
#   'Alvin and the Chipmunks: The Road Chip',
#   'Source Code',
#   'Subway',
#   'Crocodile Dundee',
#   'Valiant',
#   'The Nut Job',
#   'Under the Skin',
#   'Everest',
#   'The 6th Day',
#   'Bicentennial Man',
#   'The Faculty',
#   'DragonHeart',
#   'Royal Kill',
#   'Batman: The Dark Knight Returns, Part 2',
#   'San Andreas',
#   'Penguins of Madagascar',
#   'The Last Samurai',
#   'District 9',
#   'What Planet Are You From?',
#   'Blindness',
#   'Antz',
#   'Spaced Invaders',
#   'Hugo',
#   'Slither',
#   'My Stepmother is an Alien',
#   'The Adjustment Bureau',
#   'Metropolis',
#   'Walking With Dinosaurs',
#   'Frozen',
#   'Need for Speed',
#   'The Clan of the Cave Bear',
#   'The Finest Hours',
#   'Super 8',
#   'Monsters',
#   'Apollo 18',
#   'The Tourist',
#   'Batman Begins',
#   'The Perfect Wave',
#   'Point Break',
#   'Minions',
#   'Mars Needs Moms',
#   'Sleeper',
#   'Skyline',
#   'One for the Money',
#   'The Longest Day',
#   'Cloud Atlas',
#   'K-PAX',
#   'My Favorite Martian',
#   'Frequency',
#   'Dances with Wolves',
#   'Signs',
#   'The Sticky Fingers of Time',
#   'The Muppet Christmas Carol',
#   'The X Files: I Want to Believe',
#   'Close Encounters of the Third Kind',
#   'Jackass 3D',
#   'Supernova',
#   'Yogi Bear',
#   'Noah',
#   'Bait',
#   'The Great Raid',
#   'The Adventures of Tintin',
#   'Wrath of the Titans',
#   'Across the Universe',
#   'Alvin and the Chipmunks: The Squeakquel',
#   'Gravity',
#   'Sex Drive'],
#  ['Anna and the King',
#   'Piranha 3D',
#   'Step Up 3D',
#   'The Lucky Ones',
#   'World Trade Center',
#   'Sydney White',
#   'Glory',
#   'Amigo',
#   'Buried',
#   'Bend It Like Beckham',
#   'The Lake House',
#   'Passchendaele',
#   'Boys Dont Cry',
#   'Just Looking',
#   'Martian Child',
#   'American Gangster',
#   'Dolphins and Whales: Tribes of the Ocean',
#   'The Ugly Truth',
#   'The Great Gatsby',
#   'Teenage Mutant Ninja Turtles',
#   'The End of the Affair',
#   'Brother',
#   'North Country',
#   'Final Destination 5',
#   'Standard Operating Procedure',
#   'I, Frankenstein',
#   'Renaissance Man',
#   'Small Soldiers',
#   'Titanic',
#   'The Watch',
#   'Gods and Generals',
#   'Madagascar 3: Europes Most Wanted',
#   'The Right Stuff',
#   'Your Sisters Sister',
#   'Enough Said',
#   'The Messenger',
#   'The Peanuts Movie',
#   'Saw: The Final Chapter',
#   'Despicable Me 2',
#   'Gullivers Travels',
#   'Sea Rex 3D: Journey to a Prehistoric World',
#   'Race to Witch Mountain',
#   'East Is East',
#   'A Very Harold & Kumar Christmas',
#   'A Turtles Tale: Sammys Adventures',
#   'Cats & Dogs',
#   '3:10 to Yuma',
#   'Battle of the Year',
#   'Cats & Dogs 2 : The Revenge of Kitty Galore',
#   'Final Fantasy: The Spirits Within',
#   'Love Letters',
#   'An Education',
#   'Summer Catch',
#   'Gentlemans Agreement',
#   'Mutual Appreciation',
#   'Django Unchained',
#   'Gettysburg',
#   'American Desi',
#   'Heartbeeps',
#   'The Crying Game',
#   'Apollo 13',
#   'The Piano',
#   'Happy Feet Two',
#   'Sin City: A Dame to Kill For',
#   'Underworld: Rise of the Lycans',
#   'Case 39',
#   'A Hard Days Night',
#   'Inside Out',
#   'Despicable Me',
#   'Ravenous',
#   'High Noon',
#   'Silent Hill: Revelation 3D',
#   'My Soul to Take',
#   'Space Chimps',
#   'The Angry Birds Movie',
#   'Harts War',
#   'My Bloody Valentine',
#   'Becoming Jane',
#   'Do the Right Thing',
#   'Free Birds',
#   'My Beautiful Laundrette']]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
hey=0

rating_weights = {0: -2, 1: -1, 2:0, 3:0, 4:1, 5:2}
score_weights = {0: 5, 1:4, 2: 3, 3: 2, 4: 1} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, start=0, end = -1, movie_score = {}):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train,
    ενώ παράλληλα μπορούμε να αρχικοποιήσουμε και το movie_score το οποίο αποθηκεύονται τα score κάθε ταινίας.
    Έτσι αν έχουμε κάνει train τον recommender μας για τις πρώτες 10 ταινίες, μπορούμε να συνεχίσουμε για τις 
    υπόλοιπες χωρίς κάθε φορά να ξανά-διαμορφώνουμε το score για αυτές. Αυτό θα σας βοηθήσει στην εκτέλεση και χρονικά όταν ελέγχετε την 
    απόδοση σε υποσύνολα των ratings π.χ. πρώτες 10 ταινίες έπειτα τις επόμενες 20 κ.ο.κ.
    """
    if end == -1:
        end = len(ratings)

    ratings = ratings.iloc[range(start, end)]
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')
        similar_movies = simple_recommender(movie)
        for i in range(5):
          for similar_movie in similar_movies[i]:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[i]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[i] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 0, 10)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# 0it [00:00, ?it/s]
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# {'precision': 0.4878048780487805, 'recall': 0.2777777777777778, 'f1': 0.3539823008849558}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10, 20, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# 0it [00:00, ?it/s]
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# new search
#  5 done
#  4 done
#  3 done
#  2 done
# {'precision': 0.5185185185185185, 'recall': 0.3888888888888889, 'f1': 0.4444444444444444}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 20, 30, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))

# %% [markdown]
# {'precision': 0.4666666666666667,'recall': 0.3888888888888889, 'f1': 0.42424242424242425}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30, 50, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))

# %% [markdown]
# {'precision': 0.4266666666666667, 'recall': 0.4861111111111111, 'f1': 0.44871794871794873}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights,start = 50, movie_score= movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))

# %% [markdown]
# {'precision': 0.5152375144945044, 'recall': 0.6388888888888888, 'f1': 0.5644171779141104}

# %% [markdown]
# Κάνουμε train τον recommender μας για δίαφορα dataset με βήματα.Επίσης κρατάμε τα προηγούμενα scores στο moovie scores
#
# *   Ξεκινάμε με τις πρώτες 10 ταινίες
# *   Μετα τις ταινίες από 10 εώς 20
# *   Στην συνέχεια τις 20 εως 30
# *   Έπειτα τις επόμενες 20(30-50)
# *   Τέλος όλες τις 50 ταινίες
#
# Το μέγεθος του train test και το f1 score είναι ανάλογα όπως είναι λογικό, καθώς με μικρό train set δεν μπορούμε να βρούμε πολλές similar movies με αποτέλεσμα να επιτυγχάνουμε χαμηλό recall στο test set. Το precision score κυμαίνεται απο 45-55%. Αυτό σημαίνει ότι τα βάρη που χρησιμοποιούμε για την αξιολόγηση των similar movies δεν είναι απολύτως κατάλληλα αλλά παράγουν σταθερά αποτέλεσματα ανεξάρτητα του μεγέθους του train set.
#
# Τα αποτελέσματα μας δεν ήταν ιδιαίτερα καλά και ίσως βελτιώνονταν με την περαιτέρω αύξηση του train set. Ένας άλλος λόγος είναι ότι η βαθμολογία του χρήστη είναι εξατομηκευμένη και πολλές φορές αντιτίθεται σε "βασικούς" κανόνες ( πχ 1.5 για το Roki και 4 για το Rambo, ενώ θα λέγαμε ότι οι δύο ταινίες είναι αρκετά παρόμοιες). Επίσης, μία άλλη μέθοδος που θα μπορούσαμε να χρησιμοποιήσουμε στην άσκηση είναι η ανάμειξη κριτικών διαφόρων χρηστών ώστε να αυξήσουμε τα δεδομένα μας και να παράγουμε ένα γενικότερο recommendation system.
#
# Τέλος, ένας άλλος τρόπος εργασίας για την δημιουργία ενός recommendation system θα μπορούσε να επιτευχθεί με τη χρήση μεθόδων νευρωνικών δικτύων όπου θα είχαμε αυτόματη βελτιστοποίηση των βαρών και μπορεί να επιτυγχάναμε καλύτερα αποτελέσματα.
#
# **Σημείωση:** Στα τρία τελευταία train recommender δεν φαίνεται ο χρόνος που πήρε καθώς και οι επαναλήψεις. Αυτό συνέβη διότι τρέξαμε αυτά τα κέλια μέσω ενός λάπτοπ και λόγω αποτυχίας αποθήκευσης δεν εμφανίστηκαν. Δεν μπορέσαμε να ξανατρέξουμε τα κελία λόγω του αρκετού χρόνου που χρειαζόταν. Τα παραπάνω αποτελέσματα όμως είναι αυτά που είχαμε δεί όταν έτρεξαν, καθώς είχαν σημειώθει για τον σχολιασμό που θα γινόταν αργότερα.
